# %% [markdown]
# # Modules & Configuration

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.utils import compute_class_weight
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from statistics import mean
from sklearn.model_selection import StratifiedKFold

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

from collections import Counter
import multiprocessing

import os
import shutil
import tabnet

from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
# Configuration

# Pandas
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)
pd.set_option("display.max_rows", None)
pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.precision", 2)
pd.set_option('display.width', 1000)
pd.options.mode.chained_assignment = None

n_cpus = multiprocessing.cpu_count()

# Seaborn
sns.set()
color_blue = "#0089fa"
color_pink = "#ff0051"
colors = [color_blue, color_pink]
customPalette = sns.set_palette(sns.color_palette(colors))
customDiverging = sns.diverging_palette(207, 341, as_cmap=True)

# Avoid warnings
#warnings.filterwarnings('ignore')



print("Available CPUs: ", n_cpus)
# Out:
# Available CPUs:  16

# %%
class_names_complete = ['Sanos', 'Talasemias', 'Hemoglobinopatías', 'A.Ferropénicas', 'A.Crónico']

# %% [markdown]
# # Data Loading

# %%
#Load CSV fie
CBC_file_dir = "data/ProcessedData-2021-Filtrados.csv"
CBC = pd.read_csv(CBC_file_dir, error_bad_lines=True)
CBC["Clase"] = CBC["Clase"].astype(int)
print('File loaded, shape:(%s, %s)' %((len(CBC), len(CBC.iloc[0]))))
# Out:
# File loaded, shape:(3295, 18)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_27156\355433997.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   CBC = pd.read_csv(CBC_file_dir, error_bad_lines=True)

# %% [markdown]
# # Data Preprocessing

# %%
healthy = CBC.loc[CBC['Clase'] == 0]
thalassemias = CBC.loc[CBC['Clase'] == 1]
hemog = CBC.loc[CBC['Clase'] == 2]
anemiasferropenicas = CBC.loc[CBC['Clase'] == 3]
anemiastranscronico = CBC.loc[CBC['Clase'] == 4]

#Pick only specific thalassemias
#thalassemias = thalassemias.loc[(thalassemias['TipoClase'] == 7) | (thalassemias['TipoClase'] == 4) | (thalassemias['TipoClase'] == 3)]

CBC = pd.concat([healthy, hemog, anemiasferropenicas, anemiastranscronico, thalassemias])
print(CBC['Clase'].value_counts(sort=False))
# Out:
# 0    863
# 2    798
# 3    455
# 4    504
# 1    675
# Name: Clase, dtype: int64

# %%
CBC = CBC.sample(frac = 1)

labels = CBC['Clase']
CBC = CBC.drop('Clase', axis=1)
CBC = CBC.drop('TipoClase', axis=1)
df_columns = CBC.columns
CBC.replace(0,CBC.mean(axis=0),inplace=True)
CBC['Clase'] = labels

CBC['Clase'] = np.floor(pd.to_numeric(CBC['Clase'], errors='coerce')).astype('Int64')

# %%
print(df_columns)
# Out:
# Index(['Edad', 'WBC', 'LYAB', 'MOAB', 'NEAB', 'EO', 'BA', 'HEMA', 'HGB', 'HTO', 'VCM', 'MCH', 'CHCM', 'RDW', 'PLT', 'VPM'], dtype='object')

# %%
CBC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3295 entries, 2365 to 1601
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Edad    3295 non-null   float64
#  1   WBC     3295 non-null   float64
#  2   LYAB    3295 non-null   float64
#  3   MOAB    3295 non-null   float64
#  4   NEAB    3295 non-null   float64
#  5   EO      3295 non-null   float64
#  6   BA      3295 non-null   float64
#  7   HEMA    3295 non-null   float64
#  8   HGB     3295 non-null   float64
#  9   HTO     3295 non-null   float64
#  10  VCM     3295 non-null   float64
#  11  MCH     3295 non-null   float64
#  12  CHCM    3295 non-null   float64
#  13  RDW     3295 non-null   float64
#  14  PLT     3295 non-null   float64
#  15  VPM     3295 non-null   float64
#  16  Clase   3295 non-null   Int64
# dtypes: Int64(1), float64(16)
# memory usage: 466.6 KB

# %%
print(CBC.describe())
# Out:
#            Edad       WBC      LYAB     MOAB      NEAB        EO       BA      HEMA      HGB      HTO      VCM       MCH      CHCM       RDW       PLT      VPM    Clase
# count  3.30e+03  3.30e+03  3.30e+03  3295.00  3.30e+03  3.30e+03  3295.00  3.30e+03  3295.00  3295.00  3295.00  3.30e+03  3.30e+03  3.30e+03  3.30e+03  3295.00  3295.00
# mean   5.41e-01  1.52e-01  6.94e-02     0.20  1.82e-01  8.66e-02     0.10  3.51e-01     0.51     0.46     0.41  4.00e-01  6.51e-01  1.58e-01  1.92e-01     0.39     1.72
# std    2.27e-01  7.40e-02  5.62e-02     0.10  1.03e-01  8.30e-02     0.07  1.24e-01     0.13     0.13     0.14  1.49e-01  1.21e-01  1.10e-01  9.86e-02     0.14     1.39
# min    9.80e-03  2.24e-03  3.30e-03     0.04  4.55e-03  2.86e-03     0.02  5.17e-03     0.12     0.07     0.03  6.56e-03  7.69e-03  3.42e-03  1.74e-03     0.06     0.00
# 25%    3.92e-01  1.05e-01  3.96e-02     0.14  1.18e-01  3.71e-02     0.07  2.59e-01     0.41     0.36     0.32  2.98e-01  5.92e-01  8.22e-02  1.33e-01     0.30     0.00
# 50%    5.49e-01  1.41e-01  5.94e-02     0.18  1.68e-01  6.57e-02     0.09  3.53e-01     0.51     0.46     0.43  4.30e-01  6.69e-01  1.27e-01  1.81e-01     0.38     2.00
# 75%    7.35e-01  1.84e-01  8.58e-02     0.25  2.18e-01  1.09e-01     0.12  4.36e-01     0.61     0.54     0.50  5.02e-01  7.31e-01  1.99e-01  2.34e-01     0.47     3.00
# max    1.00e+00  1.00e+00  1.00e+00     1.00  1.00e+00  1.00e+00     1.00  1.00e+00     1.00     1.00     1.00  1.00e+00  1.00e+00  1.00e+00  1.00e+00     1.00     4.00

# %% [markdown]
# # TabNet

# %%
BATCH_SIZE = 100

# %%
def transform(ds):
    labels = ds['Clase']
    ds.pop('Clase')
    
    x = ds
    y = tf.one_hot(labels, 5)
    return x, y

# %%
col_names = df_columns
print(len(col_names))

x_train, x_test, y_train, y_test = train_test_split(CBC, labels, test_size = 0.3, stratify=labels, shuffle=True)

ds_train = tf.data.Dataset.from_tensor_slices(x_train.to_dict(orient="list"))
ds_train = ds_train.map(transform)
ds_train = ds_train.batch(BATCH_SIZE)

ds_test = tf.data.Dataset.from_tensor_slices(x_test.to_dict(orient="list"))
ds_test = ds_test.map(transform)
ds_test = ds_test.batch(BATCH_SIZE)
# Out:
# 16

# %%
feature_columns = []
for col_name in col_names:
    feature_columns.append(tf.feature_column.numeric_column(col_name))

# %%
model = tabnet.TabNetClassifier(feature_columns, num_classes=5,
                                feature_dim=17, output_dim=5,
                                num_decision_steps=1, relaxation_factor=1.0,
                                sparsity_coefficient=1e-5, batch_momentum=0.98,
                                virtual_batch_size=None, norm_type='group',
                                num_groups=1)

lr = tf.keras.optimizers.schedules.ExponentialDecay(0.0001, decay_steps=1000, decay_rate=0.9, staircase=True)
optimizer = tf.keras.optimizers.Adam(lr)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callback_es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

history = model.fit(ds_train, epochs=600, validation_data=ds_test, verbose=2, callbacks=[callback_es])

model.summary()
# Out:
# Epoch 1/600
# 24/24 - 1s - loss: 1.7605 - accuracy: 0.2042 - val_loss: 1.7370 - val_accuracy: 0.2032 - 1s/epoch - 58ms/step
# Epoch 2/600
# 24/24 - 0s - loss: 1.7177 - accuracy: 0.2042 - val_loss: 1.6992 - val_accuracy: 0.2032 - 122ms/epoch - 5ms/step
# Epoch 3/600
# 24/24 - 0s - loss: 1.6834 - accuracy: 0.2042 - val_loss: 1.6688 - val_accuracy: 0.2032 - 70ms/epoch - 3ms/step
# Epoch 4/600
# 24/24 - 0s - loss: 1.6559 - accuracy: 0.2042 - val_loss: 1.6445 - val_accuracy: 0.2032 - 70ms/epoch - 3ms/step
# Epoch 5/600
# 24/24 - 0s - loss: 1.6337 - accuracy: 0.2038 - val_loss: 1.6246 - val_accuracy: 0.2022 - 69ms/epoch - 3ms/step
# Epoch 6/600
# 24/24 - 0s - loss: 1.6159 - accuracy: 0.2038 - val_loss: 1.6094 - val_accuracy: 0.2032 - 68ms/epoch - 3ms/step
# Epoch 7/600
# 24/24 - 0s - loss: 1.6031 - accuracy: 0.2038 - val_loss: 1.5983 - val_accuracy: 0.2032 - 68ms/epoch - 3ms/step
# Epoch 8/600
# 24/24 - 0s - loss: 1.5932 - accuracy: 0.2038 - val_loss: 1.5887 - val_accuracy: 0.2032 - 69ms/epoch - 3ms/step
# Epoch 9/600
# 24/24 - 0s - loss: 1.5842 - accuracy: 0.2047 - val_loss: 1.5795 - val_accuracy: 0.2032 - 70ms/epoch - 3ms/step
# Epoch 10/600
# 24/24 - 0s - loss: 1.5755 - accuracy: 0.2051 - val_loss: 1.5703 - val_accuracy: 0.2032 - 70ms/epoch - 3ms/step
# Epoch 11/600
# 24/24 - 0s - loss: 1.5666 - accuracy: 0.2051 - val_loss: 1.5611 - val_accuracy: 0.2042 - 71ms/epoch - 3ms/step
# Epoch 12/600
# 24/24 - 0s - loss: 1.5577 - accuracy: 0.2060 - val_loss: 1.5518 - val_accuracy: 0.2093 - 73ms/epoch - 3ms/step
# Epoch 13/600
# 24/24 - 0s - loss: 1.5489 - accuracy: 0.2073 - val_loss: 1.5425 - val_accuracy: 0.2103 - 67ms/epoch - 3ms/step
# Epoch 14/600
# 24/24 - 0s - loss: 1.5401 - accuracy: 0.2112 - val_loss: 1.5334 - val_accuracy: 0.2123 - 65ms/epoch - 3ms/step
# Epoch 15/600
# 24/24 - 0s - loss: 1.5313 - accuracy: 0.2147 - val_loss: 1.5244 - val_accuracy: 0.2154 - 64ms/epoch - 3ms/step
# Epoch 16/600
# 24/24 - 0s - loss: 1.5225 - accuracy: 0.2190 - val_loss: 1.5155 - val_accuracy: 0.2194 - 65ms/epoch - 3ms/step
# Epoch 17/600
# 24/24 - 0s - loss: 1.5135 - accuracy: 0.2242 - val_loss: 1.5067 - val_accuracy: 0.2224 - 64ms/epoch - 3ms/step
# Epoch 18/600
# 24/24 - 0s - loss: 1.5044 - accuracy: 0.2259 - val_loss: 1.4980 - val_accuracy: 0.2265 - 64ms/epoch - 3ms/step
# Epoch 19/600
# 24/24 - 0s - loss: 1.4953 - accuracy: 0.2281 - val_loss: 1.4893 - val_accuracy: 0.2235 - 65ms/epoch - 3ms/step
# Epoch 20/600
# 24/24 - 0s - loss: 1.4863 - accuracy: 0.2342 - val_loss: 1.4808 - val_accuracy: 0.2295 - 64ms/epoch - 3ms/step
# Epoch 21/600
# 24/24 - 0s - loss: 1.4773 - accuracy: 0.2424 - val_loss: 1.4721 - val_accuracy: 0.2386 - 63ms/epoch - 3ms/step
# Epoch 22/600
# 24/24 - 0s - loss: 1.4685 - accuracy: 0.2498 - val_loss: 1.4637 - val_accuracy: 0.2508 - 67ms/epoch - 3ms/step
# Epoch 23/600
# 24/24 - 0s - loss: 1.4600 - accuracy: 0.2554 - val_loss: 1.4556 - val_accuracy: 0.2588 - 69ms/epoch - 3ms/step
# Epoch 24/600
# 24/24 - 0s - loss: 1.4519 - accuracy: 0.2576 - val_loss: 1.4479 - val_accuracy: 0.2679 - 69ms/epoch - 3ms/step
# Epoch 25/600
# 24/24 - 0s - loss: 1.4440 - accuracy: 0.2628 - val_loss: 1.4406 - val_accuracy: 0.2730 - 69ms/epoch - 3ms/step
# Epoch 26/600
# 24/24 - 0s - loss: 1.4364 - accuracy: 0.2654 - val_loss: 1.4337 - val_accuracy: 0.2770 - 65ms/epoch - 3ms/step
# Epoch 27/600
# 24/24 - 0s - loss: 1.4291 - accuracy: 0.2676 - val_loss: 1.4269 - val_accuracy: 0.2781 - 65ms/epoch - 3ms/step
# Epoch 28/600
# 24/24 - 0s - loss: 1.4220 - accuracy: 0.2689 - val_loss: 1.4206 - val_accuracy: 0.2851 - 69ms/epoch - 3ms/step
# Epoch 29/600
# 24/24 - 0s - loss: 1.4152 - accuracy: 0.2689 - val_loss: 1.4142 - val_accuracy: 0.2882 - 66ms/epoch - 3ms/step
# Epoch 30/600
# 24/24 - 0s - loss: 1.4085 - accuracy: 0.2719 - val_loss: 1.4083 - val_accuracy: 0.2902 - 65ms/epoch - 3ms/step
# Epoch 31/600
# 24/24 - 0s - loss: 1.4020 - accuracy: 0.2697 - val_loss: 1.4022 - val_accuracy: 0.2902 - 68ms/epoch - 3ms/step
# Epoch 32/600
# 24/24 - 0s - loss: 1.3956 - accuracy: 0.2736 - val_loss: 1.3966 - val_accuracy: 0.2922 - 65ms/epoch - 3ms/step
# Epoch 33/600
# 24/24 - 0s - loss: 1.3895 - accuracy: 0.2745 - val_loss: 1.3908 - val_accuracy: 0.2902 - 66ms/epoch - 3ms/step
# Epoch 34/600
# 24/24 - 0s - loss: 1.3835 - accuracy: 0.2745 - val_loss: 1.3852 - val_accuracy: 0.2892 - 65ms/epoch - 3ms/step
# Epoch 35/600
# 24/24 - 0s - loss: 1.3775 - accuracy: 0.2754 - val_loss: 1.3799 - val_accuracy: 0.2912 - 65ms/epoch - 3ms/step
# Epoch 36/600
# 24/24 - 0s - loss: 1.3718 - accuracy: 0.2741 - val_loss: 1.3743 - val_accuracy: 0.2882 - 68ms/epoch - 3ms/step
# Epoch 37/600
# 24/24 - 0s - loss: 1.3662 - accuracy: 0.2771 - val_loss: 1.3692 - val_accuracy: 0.2892 - 68ms/epoch - 3ms/step
# Epoch 38/600
# 24/24 - 0s - loss: 1.3608 - accuracy: 0.2758 - val_loss: 1.3639 - val_accuracy: 0.2882 - 67ms/epoch - 3ms/step
# Epoch 39/600
# 24/24 - 0s - loss: 1.3555 - accuracy: 0.2784 - val_loss: 1.3590 - val_accuracy: 0.2861 - 66ms/epoch - 3ms/step
# Epoch 40/600
# 24/24 - 0s - loss: 1.3504 - accuracy: 0.2775 - val_loss: 1.3538 - val_accuracy: 0.2851 - 70ms/epoch - 3ms/step
# Epoch 41/600
# 24/24 - 0s - loss: 1.3454 - accuracy: 0.2775 - val_loss: 1.3489 - val_accuracy: 0.2861 - 72ms/epoch - 3ms/step
# Epoch 42/600
# 24/24 - 0s - loss: 1.3406 - accuracy: 0.4406 - val_loss: 1.3443 - val_accuracy: 0.4408 - 69ms/epoch - 3ms/step
# Epoch 43/600
# 24/24 - 0s - loss: 1.3362 - accuracy: 0.4514 - val_loss: 1.3400 - val_accuracy: 0.4439 - 66ms/epoch - 3ms/step
# Epoch 44/600
# 24/24 - 0s - loss: 1.3319 - accuracy: 0.4545 - val_loss: 1.3359 - val_accuracy: 0.4520 - 65ms/epoch - 3ms/step
# Epoch 45/600
# 24/24 - 0s - loss: 1.3278 - accuracy: 0.4592 - val_loss: 1.3317 - val_accuracy: 0.4550 - 68ms/epoch - 3ms/step
# Epoch 46/600
# 24/24 - 0s - loss: 1.3238 - accuracy: 0.4627 - val_loss: 1.3278 - val_accuracy: 0.4580 - 67ms/epoch - 3ms/step
# Epoch 47/600
# 24/24 - 0s - loss: 1.3197 - accuracy: 0.4662 - val_loss: 1.3237 - val_accuracy: 0.4580 - 66ms/epoch - 3ms/step
# Epoch 48/600
# 24/24 - 0s - loss: 1.3159 - accuracy: 0.4640 - val_loss: 1.3199 - val_accuracy: 0.4651 - 70ms/epoch - 3ms/step
# Epoch 49/600
# 24/24 - 0s - loss: 1.3120 - accuracy: 0.4653 - val_loss: 1.3162 - val_accuracy: 0.4681 - 72ms/epoch - 3ms/step
# Epoch 50/600
# 24/24 - 0s - loss: 1.3082 - accuracy: 0.4696 - val_loss: 1.3123 - val_accuracy: 0.4712 - 68ms/epoch - 3ms/step
# Epoch 51/600
# 24/24 - 0s - loss: 1.3045 - accuracy: 0.4718 - val_loss: 1.3088 - val_accuracy: 0.4712 - 70ms/epoch - 3ms/step
# Epoch 52/600
# 24/24 - 0s - loss: 1.3008 - accuracy: 0.4766 - val_loss: 1.3052 - val_accuracy: 0.4762 - 75ms/epoch - 3ms/step
# Epoch 53/600
# 24/24 - 0s - loss: 1.2971 - accuracy: 0.4792 - val_loss: 1.3015 - val_accuracy: 0.4823 - 72ms/epoch - 3ms/step
# Epoch 54/600
# 24/24 - 0s - loss: 1.2936 - accuracy: 0.4805 - val_loss: 1.2981 - val_accuracy: 0.4843 - 73ms/epoch - 3ms/step
# Epoch 55/600
# 24/24 - 0s - loss: 1.2900 - accuracy: 0.4831 - val_loss: 1.2947 - val_accuracy: 0.4853 - 73ms/epoch - 3ms/step
# Epoch 56/600
# 24/24 - 0s - loss: 1.2865 - accuracy: 0.4840 - val_loss: 1.2913 - val_accuracy: 0.4874 - 74ms/epoch - 3ms/step
# Epoch 57/600
# 24/24 - 0s - loss: 1.2830 - accuracy: 0.4883 - val_loss: 1.2878 - val_accuracy: 0.4863 - 72ms/epoch - 3ms/step
# Epoch 58/600
# 24/24 - 0s - loss: 1.2796 - accuracy: 0.4900 - val_loss: 1.2846 - val_accuracy: 0.4863 - 66ms/epoch - 3ms/step
# Epoch 59/600
# 24/24 - 0s - loss: 1.2761 - accuracy: 0.4913 - val_loss: 1.2814 - val_accuracy: 0.4863 - 66ms/epoch - 3ms/step
# Epoch 60/600
# 24/24 - 0s - loss: 1.2727 - accuracy: 0.4913 - val_loss: 1.2782 - val_accuracy: 0.4874 - 63ms/epoch - 3ms/step
# Epoch 61/600
# 24/24 - 0s - loss: 1.2692 - accuracy: 0.4931 - val_loss: 1.2749 - val_accuracy: 0.4894 - 69ms/epoch - 3ms/step
# Epoch 62/600
# 24/24 - 0s - loss: 1.2660 - accuracy: 0.4939 - val_loss: 1.2720 - val_accuracy: 0.4894 - 75ms/epoch - 3ms/step
# Epoch 63/600
# 24/24 - 0s - loss: 1.2626 - accuracy: 0.4948 - val_loss: 1.2689 - val_accuracy: 0.4894 - 71ms/epoch - 3ms/step
# Epoch 64/600
# 24/24 - 0s - loss: 1.2593 - accuracy: 0.4974 - val_loss: 1.2659 - val_accuracy: 0.4904 - 67ms/epoch - 3ms/step
# Epoch 65/600
# 24/24 - 0s - loss: 1.2560 - accuracy: 0.5000 - val_loss: 1.2629 - val_accuracy: 0.4894 - 65ms/epoch - 3ms/step
# Epoch 66/600
# 24/24 - 0s - loss: 1.2530 - accuracy: 0.4983 - val_loss: 1.2601 - val_accuracy: 0.4904 - 74ms/epoch - 3ms/step
# Epoch 67/600
# 24/24 - 0s - loss: 1.2498 - accuracy: 0.5000 - val_loss: 1.2572 - val_accuracy: 0.4934 - 67ms/epoch - 3ms/step
# Epoch 68/600
# 24/24 - 0s - loss: 1.2466 - accuracy: 0.5022 - val_loss: 1.2544 - val_accuracy: 0.4944 - 69ms/epoch - 3ms/step
# Epoch 69/600
# 24/24 - 0s - loss: 1.2436 - accuracy: 0.5039 - val_loss: 1.2516 - val_accuracy: 0.4965 - 68ms/epoch - 3ms/step
# Epoch 70/600
# 24/24 - 0s - loss: 1.2407 - accuracy: 0.5035 - val_loss: 1.2489 - val_accuracy: 0.4965 - 67ms/epoch - 3ms/step
# Epoch 71/600
# 24/24 - 0s - loss: 1.2376 - accuracy: 0.5048 - val_loss: 1.2463 - val_accuracy: 0.4975 - 68ms/epoch - 3ms/step
# Epoch 72/600
# 24/24 - 0s - loss: 1.2347 - accuracy: 0.5052 - val_loss: 1.2436 - val_accuracy: 0.4985 - 74ms/epoch - 3ms/step
# Epoch 73/600
# 24/24 - 0s - loss: 1.2318 - accuracy: 0.5061 - val_loss: 1.2411 - val_accuracy: 0.4995 - 75ms/epoch - 3ms/step
# Epoch 74/600
# 24/24 - 0s - loss: 1.2289 - accuracy: 0.5065 - val_loss: 1.2385 - val_accuracy: 0.4995 - 70ms/epoch - 3ms/step
# Epoch 75/600
# 24/24 - 0s - loss: 1.2262 - accuracy: 0.5065 - val_loss: 1.2361 - val_accuracy: 0.5005 - 68ms/epoch - 3ms/step
# Epoch 76/600
# 24/24 - 0s - loss: 1.2234 - accuracy: 0.5069 - val_loss: 1.2336 - val_accuracy: 0.4995 - 70ms/epoch - 3ms/step
# Epoch 77/600
# 24/24 - 0s - loss: 1.2208 - accuracy: 0.5069 - val_loss: 1.2313 - val_accuracy: 0.5005 - 69ms/epoch - 3ms/step
# Epoch 78/600
# 24/24 - 0s - loss: 1.2180 - accuracy: 0.5078 - val_loss: 1.2290 - val_accuracy: 0.5025 - 65ms/epoch - 3ms/step
# Epoch 79/600
# 24/24 - 0s - loss: 1.2154 - accuracy: 0.5100 - val_loss: 1.2267 - val_accuracy: 0.5066 - 65ms/epoch - 3ms/step
# Epoch 80/600
# 24/24 - 0s - loss: 1.2129 - accuracy: 0.5104 - val_loss: 1.2245 - val_accuracy: 0.5066 - 66ms/epoch - 3ms/step
# Epoch 81/600
# 24/24 - 0s - loss: 1.2103 - accuracy: 0.5104 - val_loss: 1.2223 - val_accuracy: 0.5096 - 64ms/epoch - 3ms/step
# Epoch 82/600
# 24/24 - 0s - loss: 1.2079 - accuracy: 0.5100 - val_loss: 1.2202 - val_accuracy: 0.5096 - 65ms/epoch - 3ms/step
# Epoch 83/600
# 24/24 - 0s - loss: 1.2054 - accuracy: 0.5104 - val_loss: 1.2181 - val_accuracy: 0.5076 - 63ms/epoch - 3ms/step
# Epoch 84/600
# 24/24 - 0s - loss: 1.2031 - accuracy: 0.5108 - val_loss: 1.2162 - val_accuracy: 0.5056 - 64ms/epoch - 3ms/step
# Epoch 85/600
# 24/24 - 0s - loss: 1.2009 - accuracy: 0.5117 - val_loss: 1.2143 - val_accuracy: 0.5056 - 65ms/epoch - 3ms/step
# Epoch 86/600
# 24/24 - 0s - loss: 1.1987 - accuracy: 0.5108 - val_loss: 1.2126 - val_accuracy: 0.5056 - 68ms/epoch - 3ms/step
# Epoch 87/600
# 24/24 - 0s - loss: 1.1968 - accuracy: 0.5108 - val_loss: 1.2108 - val_accuracy: 0.5056 - 72ms/epoch - 3ms/step
# Epoch 88/600
# 24/24 - 0s - loss: 1.1947 - accuracy: 0.5113 - val_loss: 1.2090 - val_accuracy: 0.5056 - 72ms/epoch - 3ms/step
# Epoch 89/600
# 24/24 - 0s - loss: 1.1926 - accuracy: 0.5117 - val_loss: 1.2074 - val_accuracy: 0.5056 - 66ms/epoch - 3ms/step
# Epoch 90/600
# 24/24 - 0s - loss: 1.1907 - accuracy: 0.5121 - val_loss: 1.2058 - val_accuracy: 0.5066 - 67ms/epoch - 3ms/step
# Epoch 91/600
# 24/24 - 0s - loss: 1.1888 - accuracy: 0.5121 - val_loss: 1.2041 - val_accuracy: 0.5046 - 69ms/epoch - 3ms/step
# Epoch 92/600
# 24/24 - 0s - loss: 1.1869 - accuracy: 0.5121 - val_loss: 1.2026 - val_accuracy: 0.5046 - 68ms/epoch - 3ms/step
# Epoch 93/600
# 24/24 - 0s - loss: 1.1850 - accuracy: 0.5126 - val_loss: 1.2009 - val_accuracy: 0.5046 - 66ms/epoch - 3ms/step
# Epoch 94/600
# 24/24 - 0s - loss: 1.1830 - accuracy: 0.5121 - val_loss: 1.1994 - val_accuracy: 0.5035 - 71ms/epoch - 3ms/step
# Epoch 95/600
# 24/24 - 0s - loss: 1.1813 - accuracy: 0.5126 - val_loss: 1.1980 - val_accuracy: 0.5035 - 70ms/epoch - 3ms/step
# Epoch 96/600
# 24/24 - 0s - loss: 1.1796 - accuracy: 0.5130 - val_loss: 1.1965 - val_accuracy: 0.5035 - 66ms/epoch - 3ms/step
# Epoch 97/600
# 24/24 - 0s - loss: 1.1778 - accuracy: 0.5126 - val_loss: 1.1950 - val_accuracy: 0.5056 - 71ms/epoch - 3ms/step
# Epoch 98/600
# 24/24 - 0s - loss: 1.1760 - accuracy: 0.5130 - val_loss: 1.1937 - val_accuracy: 0.5056 - 65ms/epoch - 3ms/step
# Epoch 99/600
# 24/24 - 0s - loss: 1.1743 - accuracy: 0.5134 - val_loss: 1.1923 - val_accuracy: 0.5035 - 68ms/epoch - 3ms/step
# Epoch 100/600
# 24/24 - 0s - loss: 1.1727 - accuracy: 0.5143 - val_loss: 1.1909 - val_accuracy: 0.5035 - 74ms/epoch - 3ms/step
# Epoch 101/600
# 24/24 - 0s - loss: 1.1709 - accuracy: 0.5147 - val_loss: 1.1895 - val_accuracy: 0.5035 - 77ms/epoch - 3ms/step
# Epoch 102/600
# 24/24 - 0s - loss: 1.1693 - accuracy: 0.5160 - val_loss: 1.1882 - val_accuracy: 0.5035 - 71ms/epoch - 3ms/step
# Epoch 103/600
# 24/24 - 0s - loss: 1.1677 - accuracy: 0.5173 - val_loss: 1.1869 - val_accuracy: 0.5056 - 69ms/epoch - 3ms/step
# Epoch 104/600
# 24/24 - 0s - loss: 1.1661 - accuracy: 0.5173 - val_loss: 1.1856 - val_accuracy: 0.5056 - 70ms/epoch - 3ms/step
# Epoch 105/600
# 24/24 - 0s - loss: 1.1645 - accuracy: 0.5169 - val_loss: 1.1842 - val_accuracy: 0.5066 - 72ms/epoch - 3ms/step
# Epoch 106/600
# 24/24 - 0s - loss: 1.1629 - accuracy: 0.5182 - val_loss: 1.1830 - val_accuracy: 0.5076 - 68ms/epoch - 3ms/step
# Epoch 107/600
# 24/24 - 0s - loss: 1.1613 - accuracy: 0.5186 - val_loss: 1.1818 - val_accuracy: 0.5066 - 68ms/epoch - 3ms/step
# Epoch 108/600
# 24/24 - 0s - loss: 1.1598 - accuracy: 0.5199 - val_loss: 1.1807 - val_accuracy: 0.5076 - 68ms/epoch - 3ms/step
# Epoch 109/600
# 24/24 - 0s - loss: 1.1583 - accuracy: 0.5199 - val_loss: 1.1795 - val_accuracy: 0.5086 - 67ms/epoch - 3ms/step
# Epoch 110/600
# 24/24 - 0s - loss: 1.1567 - accuracy: 0.5208 - val_loss: 1.1783 - val_accuracy: 0.5086 - 75ms/epoch - 3ms/step
# Epoch 111/600
# 24/24 - 0s - loss: 1.1552 - accuracy: 0.5212 - val_loss: 1.1771 - val_accuracy: 0.5096 - 73ms/epoch - 3ms/step
# Epoch 112/600
# 24/24 - 0s - loss: 1.1538 - accuracy: 0.5217 - val_loss: 1.1761 - val_accuracy: 0.5096 - 66ms/epoch - 3ms/step
# Epoch 113/600
# 24/24 - 0s - loss: 1.1523 - accuracy: 0.5221 - val_loss: 1.1750 - val_accuracy: 0.5076 - 69ms/epoch - 3ms/step
# Epoch 114/600
# 24/24 - 0s - loss: 1.1509 - accuracy: 0.5221 - val_loss: 1.1739 - val_accuracy: 0.5086 - 68ms/epoch - 3ms/step
# Epoch 115/600
# 24/24 - 0s - loss: 1.1495 - accuracy: 0.5230 - val_loss: 1.1727 - val_accuracy: 0.5096 - 67ms/epoch - 3ms/step
# Epoch 116/600
# 24/24 - 0s - loss: 1.1480 - accuracy: 0.5243 - val_loss: 1.1716 - val_accuracy: 0.5086 - 66ms/epoch - 3ms/step
# Epoch 117/600
# 24/24 - 0s - loss: 1.1467 - accuracy: 0.5243 - val_loss: 1.1705 - val_accuracy: 0.5086 - 73ms/epoch - 3ms/step
# Epoch 118/600
# 24/24 - 0s - loss: 1.1453 - accuracy: 0.5243 - val_loss: 1.1695 - val_accuracy: 0.5076 - 66ms/epoch - 3ms/step
# Epoch 119/600
# 24/24 - 0s - loss: 1.1440 - accuracy: 0.5243 - val_loss: 1.1684 - val_accuracy: 0.5096 - 66ms/epoch - 3ms/step
# Epoch 120/600
# 24/24 - 0s - loss: 1.1426 - accuracy: 0.5243 - val_loss: 1.1674 - val_accuracy: 0.5096 - 65ms/epoch - 3ms/step
# Epoch 121/600
# 24/24 - 0s - loss: 1.1413 - accuracy: 0.5252 - val_loss: 1.1663 - val_accuracy: 0.5096 - 65ms/epoch - 3ms/step
# Epoch 122/600
# 24/24 - 0s - loss: 1.1399 - accuracy: 0.5243 - val_loss: 1.1652 - val_accuracy: 0.5116 - 65ms/epoch - 3ms/step
# Epoch 123/600
# 24/24 - 0s - loss: 1.1386 - accuracy: 0.5256 - val_loss: 1.1642 - val_accuracy: 0.5116 - 65ms/epoch - 3ms/step
# Epoch 124/600
# 24/24 - 0s - loss: 1.1374 - accuracy: 0.5252 - val_loss: 1.1633 - val_accuracy: 0.5126 - 67ms/epoch - 3ms/step
# Epoch 125/600
# 24/24 - 0s - loss: 1.1361 - accuracy: 0.5243 - val_loss: 1.1623 - val_accuracy: 0.5116 - 64ms/epoch - 3ms/step
# Epoch 126/600
# 24/24 - 0s - loss: 1.1349 - accuracy: 0.5243 - val_loss: 1.1614 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 127/600
# 24/24 - 0s - loss: 1.1337 - accuracy: 0.5252 - val_loss: 1.1605 - val_accuracy: 0.5116 - 68ms/epoch - 3ms/step
# Epoch 128/600
# 24/24 - 0s - loss: 1.1326 - accuracy: 0.5256 - val_loss: 1.1597 - val_accuracy: 0.5116 - 70ms/epoch - 3ms/step
# Epoch 129/600
# 24/24 - 0s - loss: 1.1315 - accuracy: 0.5260 - val_loss: 1.1588 - val_accuracy: 0.5126 - 66ms/epoch - 3ms/step
# Epoch 130/600
# 24/24 - 0s - loss: 1.1304 - accuracy: 0.5265 - val_loss: 1.1580 - val_accuracy: 0.5126 - 66ms/epoch - 3ms/step
# Epoch 131/600
# 24/24 - 0s - loss: 1.1294 - accuracy: 0.5265 - val_loss: 1.1571 - val_accuracy: 0.5126 - 64ms/epoch - 3ms/step
# Epoch 132/600
# 24/24 - 0s - loss: 1.1283 - accuracy: 0.5273 - val_loss: 1.1562 - val_accuracy: 0.5126 - 66ms/epoch - 3ms/step
# Epoch 133/600
# 24/24 - 0s - loss: 1.1271 - accuracy: 0.5282 - val_loss: 1.1554 - val_accuracy: 0.5126 - 65ms/epoch - 3ms/step
# Epoch 134/600
# 24/24 - 0s - loss: 1.1261 - accuracy: 0.5286 - val_loss: 1.1546 - val_accuracy: 0.5126 - 69ms/epoch - 3ms/step
# Epoch 135/600
# 24/24 - 0s - loss: 1.1251 - accuracy: 0.5291 - val_loss: 1.1538 - val_accuracy: 0.5126 - 76ms/epoch - 3ms/step
# Epoch 136/600
# 24/24 - 0s - loss: 1.1240 - accuracy: 0.5295 - val_loss: 1.1530 - val_accuracy: 0.5126 - 72ms/epoch - 3ms/step
# Epoch 137/600
# 24/24 - 0s - loss: 1.1229 - accuracy: 0.5295 - val_loss: 1.1522 - val_accuracy: 0.5116 - 74ms/epoch - 3ms/step
# Epoch 138/600
# 24/24 - 0s - loss: 1.1219 - accuracy: 0.5291 - val_loss: 1.1514 - val_accuracy: 0.5116 - 71ms/epoch - 3ms/step
# Epoch 139/600
# 24/24 - 0s - loss: 1.1209 - accuracy: 0.5286 - val_loss: 1.1506 - val_accuracy: 0.5106 - 74ms/epoch - 3ms/step
# Epoch 140/600
# 24/24 - 0s - loss: 1.1199 - accuracy: 0.5286 - val_loss: 1.1497 - val_accuracy: 0.5116 - 73ms/epoch - 3ms/step
# Epoch 141/600
# 24/24 - 0s - loss: 1.1188 - accuracy: 0.5295 - val_loss: 1.1489 - val_accuracy: 0.5116 - 75ms/epoch - 3ms/step
# Epoch 142/600
# 24/24 - 0s - loss: 1.1178 - accuracy: 0.5291 - val_loss: 1.1482 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 143/600
# 24/24 - 0s - loss: 1.1169 - accuracy: 0.5291 - val_loss: 1.1474 - val_accuracy: 0.5116 - 67ms/epoch - 3ms/step
# Epoch 144/600
# 24/24 - 0s - loss: 1.1158 - accuracy: 0.5299 - val_loss: 1.1466 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 145/600
# 24/24 - 0s - loss: 1.1148 - accuracy: 0.5304 - val_loss: 1.1458 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 146/600
# 24/24 - 0s - loss: 1.1139 - accuracy: 0.5291 - val_loss: 1.1451 - val_accuracy: 0.5126 - 72ms/epoch - 3ms/step
# Epoch 147/600
# 24/24 - 0s - loss: 1.1130 - accuracy: 0.5299 - val_loss: 1.1443 - val_accuracy: 0.5126 - 74ms/epoch - 3ms/step
# Epoch 148/600
# 24/24 - 0s - loss: 1.1120 - accuracy: 0.5295 - val_loss: 1.1435 - val_accuracy: 0.5126 - 67ms/epoch - 3ms/step
# Epoch 149/600
# 24/24 - 0s - loss: 1.1110 - accuracy: 0.5291 - val_loss: 1.1428 - val_accuracy: 0.5116 - 67ms/epoch - 3ms/step
# Epoch 150/600
# 24/24 - 0s - loss: 1.1101 - accuracy: 0.5282 - val_loss: 1.1421 - val_accuracy: 0.5126 - 92ms/epoch - 4ms/step
# Epoch 151/600
# 24/24 - 0s - loss: 1.1091 - accuracy: 0.5291 - val_loss: 1.1413 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 152/600
# 24/24 - 0s - loss: 1.1082 - accuracy: 0.5295 - val_loss: 1.1406 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 153/600
# 24/24 - 0s - loss: 1.1073 - accuracy: 0.5299 - val_loss: 1.1399 - val_accuracy: 0.5126 - 71ms/epoch - 3ms/step
# Epoch 154/600
# 24/24 - 0s - loss: 1.1064 - accuracy: 0.5295 - val_loss: 1.1392 - val_accuracy: 0.5147 - 80ms/epoch - 3ms/step
# Epoch 155/600
# 24/24 - 0s - loss: 1.1055 - accuracy: 0.5295 - val_loss: 1.1385 - val_accuracy: 0.5147 - 73ms/epoch - 3ms/step
# Epoch 156/600
# 24/24 - 0s - loss: 1.1045 - accuracy: 0.5295 - val_loss: 1.1378 - val_accuracy: 0.5157 - 72ms/epoch - 3ms/step
# Epoch 157/600
# 24/24 - 0s - loss: 1.1037 - accuracy: 0.5299 - val_loss: 1.1371 - val_accuracy: 0.5157 - 68ms/epoch - 3ms/step
# Epoch 158/600
# 24/24 - 0s - loss: 1.1027 - accuracy: 0.5312 - val_loss: 1.1364 - val_accuracy: 0.5157 - 69ms/epoch - 3ms/step
# Epoch 159/600
# 24/24 - 0s - loss: 1.1018 - accuracy: 0.5312 - val_loss: 1.1357 - val_accuracy: 0.5157 - 76ms/epoch - 3ms/step
# Epoch 160/600
# 24/24 - 0s - loss: 1.1010 - accuracy: 0.5308 - val_loss: 1.1350 - val_accuracy: 0.5157 - 68ms/epoch - 3ms/step
# Epoch 161/600
# 24/24 - 0s - loss: 1.1001 - accuracy: 0.5304 - val_loss: 1.1343 - val_accuracy: 0.5157 - 69ms/epoch - 3ms/step
# Epoch 162/600
# 24/24 - 0s - loss: 1.0992 - accuracy: 0.5295 - val_loss: 1.1336 - val_accuracy: 0.5167 - 71ms/epoch - 3ms/step
# Epoch 163/600
# 24/24 - 0s - loss: 1.0983 - accuracy: 0.5291 - val_loss: 1.1329 - val_accuracy: 0.5157 - 71ms/epoch - 3ms/step
# Epoch 164/600
# 24/24 - 0s - loss: 1.0974 - accuracy: 0.5295 - val_loss: 1.1321 - val_accuracy: 0.5157 - 66ms/epoch - 3ms/step
# Epoch 165/600
# 24/24 - 0s - loss: 1.0965 - accuracy: 0.5295 - val_loss: 1.1314 - val_accuracy: 0.5157 - 65ms/epoch - 3ms/step
# Epoch 166/600
# 24/24 - 0s - loss: 1.0957 - accuracy: 0.5308 - val_loss: 1.1307 - val_accuracy: 0.5157 - 69ms/epoch - 3ms/step
# Epoch 167/600
# 24/24 - 0s - loss: 1.0948 - accuracy: 0.5304 - val_loss: 1.1299 - val_accuracy: 0.5147 - 70ms/epoch - 3ms/step
# Epoch 168/600
# 24/24 - 0s - loss: 1.0939 - accuracy: 0.5308 - val_loss: 1.1292 - val_accuracy: 0.5137 - 69ms/epoch - 3ms/step
# Epoch 169/600
# 24/24 - 0s - loss: 1.0931 - accuracy: 0.5308 - val_loss: 1.1285 - val_accuracy: 0.5137 - 63ms/epoch - 3ms/step
# Epoch 170/600
# 24/24 - 0s - loss: 1.0923 - accuracy: 0.5308 - val_loss: 1.1279 - val_accuracy: 0.5137 - 63ms/epoch - 3ms/step
# Epoch 171/600
# 24/24 - 0s - loss: 1.0915 - accuracy: 0.5330 - val_loss: 1.1271 - val_accuracy: 0.5137 - 62ms/epoch - 3ms/step
# Epoch 172/600
# 24/24 - 0s - loss: 1.0906 - accuracy: 0.5334 - val_loss: 1.1264 - val_accuracy: 0.5137 - 64ms/epoch - 3ms/step
# Epoch 173/600
# 24/24 - 0s - loss: 1.0898 - accuracy: 0.5330 - val_loss: 1.1257 - val_accuracy: 0.5126 - 65ms/epoch - 3ms/step
# Epoch 174/600
# 24/24 - 0s - loss: 1.0889 - accuracy: 0.5330 - val_loss: 1.1250 - val_accuracy: 0.5126 - 63ms/epoch - 3ms/step
# Epoch 175/600
# 24/24 - 0s - loss: 1.0881 - accuracy: 0.5325 - val_loss: 1.1243 - val_accuracy: 0.5126 - 66ms/epoch - 3ms/step
# Epoch 176/600
# 24/24 - 0s - loss: 1.0873 - accuracy: 0.5321 - val_loss: 1.1237 - val_accuracy: 0.5126 - 63ms/epoch - 3ms/step
# Epoch 177/600
# 24/24 - 0s - loss: 1.0865 - accuracy: 0.5317 - val_loss: 1.1230 - val_accuracy: 0.5137 - 75ms/epoch - 3ms/step
# Epoch 178/600
# 24/24 - 0s - loss: 1.0856 - accuracy: 0.5317 - val_loss: 1.1223 - val_accuracy: 0.5137 - 68ms/epoch - 3ms/step
# Epoch 179/600
# 24/24 - 0s - loss: 1.0849 - accuracy: 0.5312 - val_loss: 1.1217 - val_accuracy: 0.5137 - 70ms/epoch - 3ms/step
# Epoch 180/600
# 24/24 - 0s - loss: 1.0840 - accuracy: 0.5312 - val_loss: 1.1210 - val_accuracy: 0.5116 - 69ms/epoch - 3ms/step
# Epoch 181/600
# 24/24 - 0s - loss: 1.0832 - accuracy: 0.5317 - val_loss: 1.1203 - val_accuracy: 0.5116 - 72ms/epoch - 3ms/step
# Epoch 182/600
# 24/24 - 0s - loss: 1.0824 - accuracy: 0.5321 - val_loss: 1.1197 - val_accuracy: 0.5126 - 67ms/epoch - 3ms/step
# Epoch 183/600
# 24/24 - 0s - loss: 1.0816 - accuracy: 0.5321 - val_loss: 1.1191 - val_accuracy: 0.5116 - 64ms/epoch - 3ms/step
# Epoch 184/600
# 24/24 - 0s - loss: 1.0808 - accuracy: 0.5325 - val_loss: 1.1184 - val_accuracy: 0.5126 - 62ms/epoch - 3ms/step
# Epoch 185/600
# 24/24 - 0s - loss: 1.0800 - accuracy: 0.5325 - val_loss: 1.1177 - val_accuracy: 0.5126 - 63ms/epoch - 3ms/step
# Epoch 186/600
# 24/24 - 0s - loss: 1.0792 - accuracy: 0.5321 - val_loss: 1.1171 - val_accuracy: 0.5126 - 69ms/epoch - 3ms/step
# Epoch 187/600
# 24/24 - 0s - loss: 1.0783 - accuracy: 0.5334 - val_loss: 1.1164 - val_accuracy: 0.5137 - 62ms/epoch - 3ms/step
# Epoch 188/600
# 24/24 - 0s - loss: 1.0775 - accuracy: 0.5330 - val_loss: 1.1158 - val_accuracy: 0.5126 - 70ms/epoch - 3ms/step
# Epoch 189/600
# 24/24 - 0s - loss: 1.0767 - accuracy: 0.5325 - val_loss: 1.1152 - val_accuracy: 0.5137 - 67ms/epoch - 3ms/step
# Epoch 190/600
# 24/24 - 0s - loss: 1.0759 - accuracy: 0.5330 - val_loss: 1.1145 - val_accuracy: 0.5137 - 77ms/epoch - 3ms/step
# Epoch 191/600
# 24/24 - 0s - loss: 1.0751 - accuracy: 0.5325 - val_loss: 1.1138 - val_accuracy: 0.5147 - 67ms/epoch - 3ms/step
# Epoch 192/600
# 24/24 - 0s - loss: 1.0744 - accuracy: 0.5330 - val_loss: 1.1132 - val_accuracy: 0.5147 - 69ms/epoch - 3ms/step
# Epoch 193/600
# 24/24 - 0s - loss: 1.0736 - accuracy: 0.5338 - val_loss: 1.1126 - val_accuracy: 0.5147 - 67ms/epoch - 3ms/step
# Epoch 194/600
# 24/24 - 0s - loss: 1.0728 - accuracy: 0.5334 - val_loss: 1.1119 - val_accuracy: 0.5147 - 66ms/epoch - 3ms/step
# Epoch 195/600
# 24/24 - 0s - loss: 1.0720 - accuracy: 0.5338 - val_loss: 1.1113 - val_accuracy: 0.5147 - 64ms/epoch - 3ms/step
# Epoch 196/600
# 24/24 - 0s - loss: 1.0712 - accuracy: 0.5334 - val_loss: 1.1106 - val_accuracy: 0.5147 - 67ms/epoch - 3ms/step
# Epoch 197/600
# 24/24 - 0s - loss: 1.0704 - accuracy: 0.5334 - val_loss: 1.1100 - val_accuracy: 0.5167 - 64ms/epoch - 3ms/step
# Epoch 198/600
# 24/24 - 0s - loss: 1.0697 - accuracy: 0.5325 - val_loss: 1.1093 - val_accuracy: 0.5157 - 65ms/epoch - 3ms/step
# Epoch 199/600
# 24/24 - 0s - loss: 1.0689 - accuracy: 0.5343 - val_loss: 1.1087 - val_accuracy: 0.5177 - 65ms/epoch - 3ms/step
# Epoch 200/600
# 24/24 - 0s - loss: 1.0681 - accuracy: 0.5338 - val_loss: 1.1081 - val_accuracy: 0.5167 - 63ms/epoch - 3ms/step
# Epoch 201/600
# 24/24 - 0s - loss: 1.0673 - accuracy: 0.5343 - val_loss: 1.1074 - val_accuracy: 0.5177 - 66ms/epoch - 3ms/step
# Epoch 202/600
# 24/24 - 0s - loss: 1.0665 - accuracy: 0.5347 - val_loss: 1.1068 - val_accuracy: 0.5177 - 71ms/epoch - 3ms/step
# Epoch 203/600
# 24/24 - 0s - loss: 1.0658 - accuracy: 0.5338 - val_loss: 1.1061 - val_accuracy: 0.5187 - 77ms/epoch - 3ms/step
# Epoch 204/600
# 24/24 - 0s - loss: 1.0650 - accuracy: 0.5343 - val_loss: 1.1055 - val_accuracy: 0.5187 - 64ms/epoch - 3ms/step
# Epoch 205/600
# 24/24 - 0s - loss: 1.0642 - accuracy: 0.5338 - val_loss: 1.1048 - val_accuracy: 0.5197 - 65ms/epoch - 3ms/step
# Epoch 206/600
# 24/24 - 0s - loss: 1.0635 - accuracy: 0.5338 - val_loss: 1.1043 - val_accuracy: 0.5187 - 66ms/epoch - 3ms/step
# Epoch 207/600
# 24/24 - 0s - loss: 1.0627 - accuracy: 0.5351 - val_loss: 1.1036 - val_accuracy: 0.5804 - 66ms/epoch - 3ms/step
# Epoch 208/600
# 24/24 - 0s - loss: 1.0619 - accuracy: 0.5941 - val_loss: 1.1029 - val_accuracy: 0.5824 - 67ms/epoch - 3ms/step
# Epoch 209/600
# 24/24 - 0s - loss: 1.0612 - accuracy: 0.5945 - val_loss: 1.1024 - val_accuracy: 0.5824 - 68ms/epoch - 3ms/step
# Epoch 210/600
# 24/24 - 0s - loss: 1.0605 - accuracy: 0.5963 - val_loss: 1.1018 - val_accuracy: 0.5834 - 64ms/epoch - 3ms/step
# Epoch 211/600
# 24/24 - 0s - loss: 1.0598 - accuracy: 0.5967 - val_loss: 1.1012 - val_accuracy: 0.5834 - 65ms/epoch - 3ms/step
# Epoch 212/600
# 24/24 - 0s - loss: 1.0591 - accuracy: 0.5976 - val_loss: 1.1007 - val_accuracy: 0.5854 - 82ms/epoch - 3ms/step
# Epoch 213/600
# 24/24 - 0s - loss: 1.0585 - accuracy: 0.5980 - val_loss: 1.1000 - val_accuracy: 0.5865 - 79ms/epoch - 3ms/step
# Epoch 214/600
# 24/24 - 0s - loss: 1.0578 - accuracy: 0.5997 - val_loss: 1.0995 - val_accuracy: 0.5865 - 68ms/epoch - 3ms/step
# Epoch 215/600
# 24/24 - 0s - loss: 1.0571 - accuracy: 0.6006 - val_loss: 1.0989 - val_accuracy: 0.5895 - 74ms/epoch - 3ms/step
# Epoch 216/600
# 24/24 - 0s - loss: 1.0564 - accuracy: 0.6019 - val_loss: 1.0983 - val_accuracy: 0.5885 - 74ms/epoch - 3ms/step
# Epoch 217/600
# 24/24 - 0s - loss: 1.0557 - accuracy: 0.6023 - val_loss: 1.0977 - val_accuracy: 0.5885 - 66ms/epoch - 3ms/step
# Epoch 218/600
# 24/24 - 0s - loss: 1.0550 - accuracy: 0.6028 - val_loss: 1.0971 - val_accuracy: 0.5885 - 65ms/epoch - 3ms/step
# Epoch 219/600
# 24/24 - 0s - loss: 1.0543 - accuracy: 0.6023 - val_loss: 1.0965 - val_accuracy: 0.5885 - 66ms/epoch - 3ms/step
# Epoch 220/600
# 24/24 - 0s - loss: 1.0536 - accuracy: 0.6032 - val_loss: 1.0959 - val_accuracy: 0.5885 - 72ms/epoch - 3ms/step
# Epoch 221/600
# 24/24 - 0s - loss: 1.0529 - accuracy: 0.6045 - val_loss: 1.0954 - val_accuracy: 0.5885 - 83ms/epoch - 3ms/step
# Epoch 222/600
# 24/24 - 0s - loss: 1.0522 - accuracy: 0.6045 - val_loss: 1.0948 - val_accuracy: 0.5885 - 64ms/epoch - 3ms/step
# Epoch 223/600
# 24/24 - 0s - loss: 1.0515 - accuracy: 0.6062 - val_loss: 1.0942 - val_accuracy: 0.5885 - 63ms/epoch - 3ms/step
# Epoch 224/600
# 24/24 - 0s - loss: 1.0509 - accuracy: 0.6062 - val_loss: 1.0937 - val_accuracy: 0.5885 - 66ms/epoch - 3ms/step
# Epoch 225/600
# 24/24 - 0s - loss: 1.0502 - accuracy: 0.6062 - val_loss: 1.0931 - val_accuracy: 0.5895 - 64ms/epoch - 3ms/step
# Epoch 226/600
# 24/24 - 0s - loss: 1.0495 - accuracy: 0.6067 - val_loss: 1.0926 - val_accuracy: 0.5915 - 72ms/epoch - 3ms/step
# Epoch 227/600
# 24/24 - 0s - loss: 1.0488 - accuracy: 0.6062 - val_loss: 1.0921 - val_accuracy: 0.5935 - 79ms/epoch - 3ms/step
# Epoch 228/600
# 24/24 - 0s - loss: 1.0481 - accuracy: 0.6062 - val_loss: 1.0915 - val_accuracy: 0.5945 - 88ms/epoch - 4ms/step
# Epoch 229/600
# 24/24 - 0s - loss: 1.0474 - accuracy: 0.6071 - val_loss: 1.0910 - val_accuracy: 0.5945 - 84ms/epoch - 3ms/step
# Epoch 230/600
# 24/24 - 0s - loss: 1.0467 - accuracy: 0.6071 - val_loss: 1.0905 - val_accuracy: 0.5956 - 73ms/epoch - 3ms/step
# Epoch 231/600
# 24/24 - 0s - loss: 1.0460 - accuracy: 0.6080 - val_loss: 1.0899 - val_accuracy: 0.5956 - 64ms/epoch - 3ms/step
# Epoch 232/600
# 24/24 - 0s - loss: 1.0453 - accuracy: 0.6080 - val_loss: 1.0894 - val_accuracy: 0.5976 - 67ms/epoch - 3ms/step
# Epoch 233/600
# 24/24 - 0s - loss: 1.0447 - accuracy: 0.6084 - val_loss: 1.0889 - val_accuracy: 0.5986 - 68ms/epoch - 3ms/step
# Epoch 234/600
# 24/24 - 0s - loss: 1.0440 - accuracy: 0.6088 - val_loss: 1.0883 - val_accuracy: 0.5976 - 67ms/epoch - 3ms/step
# Epoch 235/600
# 24/24 - 0s - loss: 1.0433 - accuracy: 0.6088 - val_loss: 1.0877 - val_accuracy: 0.5976 - 64ms/epoch - 3ms/step
# Epoch 236/600
# 24/24 - 0s - loss: 1.0426 - accuracy: 0.6097 - val_loss: 1.0872 - val_accuracy: 0.5976 - 65ms/epoch - 3ms/step
# Epoch 237/600
# 24/24 - 0s - loss: 1.0420 - accuracy: 0.6088 - val_loss: 1.0867 - val_accuracy: 0.5976 - 63ms/epoch - 3ms/step
# Epoch 238/600
# 24/24 - 0s - loss: 1.0413 - accuracy: 0.6088 - val_loss: 1.0861 - val_accuracy: 0.5986 - 64ms/epoch - 3ms/step
# Epoch 239/600
# 24/24 - 0s - loss: 1.0407 - accuracy: 0.6080 - val_loss: 1.0856 - val_accuracy: 0.5996 - 65ms/epoch - 3ms/step
# Epoch 240/600
# 24/24 - 0s - loss: 1.0400 - accuracy: 0.6093 - val_loss: 1.0850 - val_accuracy: 0.6006 - 64ms/epoch - 3ms/step
# Epoch 241/600
# 24/24 - 0s - loss: 1.0393 - accuracy: 0.6093 - val_loss: 1.0845 - val_accuracy: 0.6006 - 65ms/epoch - 3ms/step
# Epoch 242/600
# 24/24 - 0s - loss: 1.0387 - accuracy: 0.6088 - val_loss: 1.0840 - val_accuracy: 0.6006 - 64ms/epoch - 3ms/step
# Epoch 243/600
# 24/24 - 0s - loss: 1.0380 - accuracy: 0.6101 - val_loss: 1.0835 - val_accuracy: 0.6006 - 66ms/epoch - 3ms/step
# Epoch 244/600
# 24/24 - 0s - loss: 1.0373 - accuracy: 0.6106 - val_loss: 1.0829 - val_accuracy: 0.6006 - 66ms/epoch - 3ms/step
# Epoch 245/600
# 24/24 - 0s - loss: 1.0367 - accuracy: 0.6110 - val_loss: 1.0824 - val_accuracy: 0.6026 - 65ms/epoch - 3ms/step
# Epoch 246/600
# 24/24 - 0s - loss: 1.0360 - accuracy: 0.6114 - val_loss: 1.0818 - val_accuracy: 0.6016 - 63ms/epoch - 3ms/step
# Epoch 247/600
# 24/24 - 0s - loss: 1.0353 - accuracy: 0.6123 - val_loss: 1.0813 - val_accuracy: 0.6026 - 63ms/epoch - 3ms/step
# Epoch 248/600
# 24/24 - 0s - loss: 1.0347 - accuracy: 0.6132 - val_loss: 1.0808 - val_accuracy: 0.6026 - 65ms/epoch - 3ms/step
# Epoch 249/600
# 24/24 - 0s - loss: 1.0340 - accuracy: 0.6127 - val_loss: 1.0802 - val_accuracy: 0.6016 - 65ms/epoch - 3ms/step
# Epoch 250/600
# 24/24 - 0s - loss: 1.0334 - accuracy: 0.6127 - val_loss: 1.0797 - val_accuracy: 0.6006 - 62ms/epoch - 3ms/step
# Epoch 251/600
# 24/24 - 0s - loss: 1.0328 - accuracy: 0.6123 - val_loss: 1.0793 - val_accuracy: 0.6016 - 62ms/epoch - 3ms/step
# Epoch 252/600
# 24/24 - 0s - loss: 1.0322 - accuracy: 0.6132 - val_loss: 1.0788 - val_accuracy: 0.6016 - 62ms/epoch - 3ms/step
# Epoch 253/600
# 24/24 - 0s - loss: 1.0316 - accuracy: 0.6136 - val_loss: 1.0783 - val_accuracy: 0.6016 - 66ms/epoch - 3ms/step
# Epoch 254/600
# 24/24 - 0s - loss: 1.0310 - accuracy: 0.6141 - val_loss: 1.0779 - val_accuracy: 0.6026 - 63ms/epoch - 3ms/step
# Epoch 255/600
# 24/24 - 0s - loss: 1.0304 - accuracy: 0.6149 - val_loss: 1.0774 - val_accuracy: 0.6036 - 68ms/epoch - 3ms/step
# Epoch 256/600
# 24/24 - 0s - loss: 1.0298 - accuracy: 0.6149 - val_loss: 1.0770 - val_accuracy: 0.6036 - 68ms/epoch - 3ms/step
# Epoch 257/600
# 24/24 - 0s - loss: 1.0293 - accuracy: 0.6154 - val_loss: 1.0765 - val_accuracy: 0.6036 - 64ms/epoch - 3ms/step
# Epoch 258/600
# 24/24 - 0s - loss: 1.0287 - accuracy: 0.6162 - val_loss: 1.0761 - val_accuracy: 0.6036 - 64ms/epoch - 3ms/step
# Epoch 259/600
# 24/24 - 0s - loss: 1.0281 - accuracy: 0.6167 - val_loss: 1.0756 - val_accuracy: 0.6026 - 65ms/epoch - 3ms/step
# Epoch 260/600
# 24/24 - 0s - loss: 1.0275 - accuracy: 0.6167 - val_loss: 1.0752 - val_accuracy: 0.6026 - 68ms/epoch - 3ms/step
# Epoch 261/600
# 24/24 - 0s - loss: 1.0270 - accuracy: 0.6175 - val_loss: 1.0747 - val_accuracy: 0.6026 - 65ms/epoch - 3ms/step
# Epoch 262/600
# 24/24 - 0s - loss: 1.0264 - accuracy: 0.6167 - val_loss: 1.0742 - val_accuracy: 0.6026 - 64ms/epoch - 3ms/step
# Epoch 263/600
# 24/24 - 0s - loss: 1.0258 - accuracy: 0.6171 - val_loss: 1.0738 - val_accuracy: 0.6026 - 63ms/epoch - 3ms/step
# Epoch 264/600
# 24/24 - 0s - loss: 1.0252 - accuracy: 0.6167 - val_loss: 1.0733 - val_accuracy: 0.6036 - 64ms/epoch - 3ms/step
# Epoch 265/600
# 24/24 - 0s - loss: 1.0247 - accuracy: 0.6167 - val_loss: 1.0729 - val_accuracy: 0.6036 - 63ms/epoch - 3ms/step
# Epoch 266/600
# 24/24 - 0s - loss: 1.0241 - accuracy: 0.6167 - val_loss: 1.0724 - val_accuracy: 0.6026 - 66ms/epoch - 3ms/step
# Epoch 267/600
# 24/24 - 0s - loss: 1.0235 - accuracy: 0.6167 - val_loss: 1.0720 - val_accuracy: 0.6036 - 63ms/epoch - 3ms/step
# Epoch 268/600
# 24/24 - 0s - loss: 1.0229 - accuracy: 0.6158 - val_loss: 1.0715 - val_accuracy: 0.6026 - 66ms/epoch - 3ms/step
# Epoch 269/600
# 24/24 - 0s - loss: 1.0224 - accuracy: 0.6162 - val_loss: 1.0711 - val_accuracy: 0.6036 - 66ms/epoch - 3ms/step
# Epoch 270/600
# 24/24 - 0s - loss: 1.0218 - accuracy: 0.6171 - val_loss: 1.0707 - val_accuracy: 0.6036 - 69ms/epoch - 3ms/step
# Epoch 271/600
# 24/24 - 0s - loss: 1.0212 - accuracy: 0.6171 - val_loss: 1.0703 - val_accuracy: 0.6047 - 68ms/epoch - 3ms/step
# Epoch 272/600
# 24/24 - 0s - loss: 1.0206 - accuracy: 0.6180 - val_loss: 1.0699 - val_accuracy: 0.6067 - 67ms/epoch - 3ms/step
# Epoch 273/600
# 24/24 - 0s - loss: 1.0200 - accuracy: 0.6180 - val_loss: 1.0695 - val_accuracy: 0.6077 - 61ms/epoch - 3ms/step
# Epoch 274/600
# 24/24 - 0s - loss: 1.0194 - accuracy: 0.6180 - val_loss: 1.0691 - val_accuracy: 0.6067 - 63ms/epoch - 3ms/step
# Epoch 275/600
# 24/24 - 0s - loss: 1.0189 - accuracy: 0.6175 - val_loss: 1.0687 - val_accuracy: 0.6067 - 64ms/epoch - 3ms/step
# Epoch 276/600
# 24/24 - 0s - loss: 1.0183 - accuracy: 0.6184 - val_loss: 1.0683 - val_accuracy: 0.6057 - 61ms/epoch - 3ms/step
# Epoch 277/600
# 24/24 - 0s - loss: 1.0177 - accuracy: 0.6184 - val_loss: 1.0679 - val_accuracy: 0.6057 - 61ms/epoch - 3ms/step
# Epoch 278/600
# 24/24 - 0s - loss: 1.0171 - accuracy: 0.6180 - val_loss: 1.0675 - val_accuracy: 0.6047 - 63ms/epoch - 3ms/step
# Epoch 279/600
# 24/24 - 0s - loss: 1.0166 - accuracy: 0.6188 - val_loss: 1.0671 - val_accuracy: 0.6057 - 63ms/epoch - 3ms/step
# Epoch 280/600
# 24/24 - 0s - loss: 1.0160 - accuracy: 0.6193 - val_loss: 1.0667 - val_accuracy: 0.6047 - 63ms/epoch - 3ms/step
# Epoch 281/600
# 24/24 - 0s - loss: 1.0154 - accuracy: 0.6193 - val_loss: 1.0663 - val_accuracy: 0.6057 - 64ms/epoch - 3ms/step
# Epoch 282/600
# 24/24 - 0s - loss: 1.0149 - accuracy: 0.6193 - val_loss: 1.0658 - val_accuracy: 0.6047 - 68ms/epoch - 3ms/step
# Epoch 283/600
# 24/24 - 0s - loss: 1.0143 - accuracy: 0.6188 - val_loss: 1.0654 - val_accuracy: 0.6036 - 67ms/epoch - 3ms/step
# Epoch 284/600
# 24/24 - 0s - loss: 1.0138 - accuracy: 0.6193 - val_loss: 1.0650 - val_accuracy: 0.6036 - 67ms/epoch - 3ms/step
# Epoch 285/600
# 24/24 - 0s - loss: 1.0132 - accuracy: 0.6193 - val_loss: 1.0646 - val_accuracy: 0.6036 - 66ms/epoch - 3ms/step
# Epoch 286/600
# 24/24 - 0s - loss: 1.0126 - accuracy: 0.6193 - val_loss: 1.0641 - val_accuracy: 0.6036 - 62ms/epoch - 3ms/step
# Epoch 287/600
# 24/24 - 0s - loss: 1.0121 - accuracy: 0.6201 - val_loss: 1.0637 - val_accuracy: 0.6036 - 63ms/epoch - 3ms/step
# Epoch 288/600
# 24/24 - 0s - loss: 1.0115 - accuracy: 0.6201 - val_loss: 1.0633 - val_accuracy: 0.6036 - 64ms/epoch - 3ms/step
# Epoch 289/600
# 24/24 - 0s - loss: 1.0110 - accuracy: 0.6201 - val_loss: 1.0629 - val_accuracy: 0.6036 - 62ms/epoch - 3ms/step
# Epoch 290/600
# 24/24 - 0s - loss: 1.0104 - accuracy: 0.6201 - val_loss: 1.0625 - val_accuracy: 0.6036 - 67ms/epoch - 3ms/step
# Epoch 291/600
# 24/24 - 0s - loss: 1.0099 - accuracy: 0.6201 - val_loss: 1.0620 - val_accuracy: 0.6047 - 67ms/epoch - 3ms/step
# Epoch 292/600
# 24/24 - 0s - loss: 1.0093 - accuracy: 0.6206 - val_loss: 1.0616 - val_accuracy: 0.6047 - 63ms/epoch - 3ms/step
# Epoch 293/600
# 24/24 - 0s - loss: 1.0088 - accuracy: 0.6206 - val_loss: 1.0612 - val_accuracy: 0.6047 - 62ms/epoch - 3ms/step
# Epoch 294/600
# 24/24 - 0s - loss: 1.0083 - accuracy: 0.6201 - val_loss: 1.0609 - val_accuracy: 0.6047 - 62ms/epoch - 3ms/step
# Epoch 295/600
# 24/24 - 0s - loss: 1.0079 - accuracy: 0.6197 - val_loss: 1.0605 - val_accuracy: 0.6047 - 62ms/epoch - 3ms/step
# Epoch 296/600
# 24/24 - 0s - loss: 1.0073 - accuracy: 0.6197 - val_loss: 1.0601 - val_accuracy: 0.6047 - 69ms/epoch - 3ms/step
# Epoch 297/600
# 24/24 - 0s - loss: 1.0069 - accuracy: 0.6193 - val_loss: 1.0597 - val_accuracy: 0.6047 - 66ms/epoch - 3ms/step
# Epoch 298/600
# 24/24 - 0s - loss: 1.0064 - accuracy: 0.6193 - val_loss: 1.0593 - val_accuracy: 0.6047 - 63ms/epoch - 3ms/step
# Epoch 299/600
# 24/24 - 0s - loss: 1.0059 - accuracy: 0.6193 - val_loss: 1.0590 - val_accuracy: 0.6057 - 67ms/epoch - 3ms/step
# Epoch 300/600
# 24/24 - 0s - loss: 1.0054 - accuracy: 0.6197 - val_loss: 1.0586 - val_accuracy: 0.6057 - 66ms/epoch - 3ms/step
# Epoch 301/600
# 24/24 - 0s - loss: 1.0049 - accuracy: 0.6206 - val_loss: 1.0583 - val_accuracy: 0.6057 - 65ms/epoch - 3ms/step
# Epoch 302/600
# 24/24 - 0s - loss: 1.0045 - accuracy: 0.6210 - val_loss: 1.0579 - val_accuracy: 0.6067 - 67ms/epoch - 3ms/step
# Epoch 303/600
# 24/24 - 0s - loss: 1.0040 - accuracy: 0.6210 - val_loss: 1.0575 - val_accuracy: 0.6067 - 65ms/epoch - 3ms/step
# Epoch 304/600
# 24/24 - 0s - loss: 1.0035 - accuracy: 0.6210 - val_loss: 1.0572 - val_accuracy: 0.6067 - 67ms/epoch - 3ms/step
# Epoch 305/600
# 24/24 - 0s - loss: 1.0030 - accuracy: 0.6210 - val_loss: 1.0568 - val_accuracy: 0.6067 - 67ms/epoch - 3ms/step
# Epoch 306/600
# 24/24 - 0s - loss: 1.0026 - accuracy: 0.6206 - val_loss: 1.0565 - val_accuracy: 0.6067 - 66ms/epoch - 3ms/step
# Epoch 307/600
# 24/24 - 0s - loss: 1.0021 - accuracy: 0.6214 - val_loss: 1.0561 - val_accuracy: 0.6057 - 63ms/epoch - 3ms/step
# Epoch 308/600
# 24/24 - 0s - loss: 1.0016 - accuracy: 0.6210 - val_loss: 1.0557 - val_accuracy: 0.6057 - 66ms/epoch - 3ms/step
# Epoch 309/600
# 24/24 - 0s - loss: 1.0012 - accuracy: 0.6210 - val_loss: 1.0553 - val_accuracy: 0.6057 - 69ms/epoch - 3ms/step
# Epoch 310/600
# 24/24 - 0s - loss: 1.0007 - accuracy: 0.6206 - val_loss: 1.0550 - val_accuracy: 0.6047 - 69ms/epoch - 3ms/step
# Epoch 311/600
# 24/24 - 0s - loss: 1.0002 - accuracy: 0.6214 - val_loss: 1.0546 - val_accuracy: 0.6057 - 71ms/epoch - 3ms/step
# Epoch 312/600
# 24/24 - 0s - loss: 0.9998 - accuracy: 0.6214 - val_loss: 1.0543 - val_accuracy: 0.6057 - 66ms/epoch - 3ms/step
# Epoch 313/600
# 24/24 - 0s - loss: 0.9993 - accuracy: 0.6214 - val_loss: 1.0539 - val_accuracy: 0.6057 - 64ms/epoch - 3ms/step
# Epoch 314/600
# 24/24 - 0s - loss: 0.9988 - accuracy: 0.6214 - val_loss: 1.0536 - val_accuracy: 0.6057 - 65ms/epoch - 3ms/step
# Epoch 315/600
# 24/24 - 0s - loss: 0.9984 - accuracy: 0.6214 - val_loss: 1.0532 - val_accuracy: 0.6057 - 75ms/epoch - 3ms/step
# Epoch 316/600
# 24/24 - 0s - loss: 0.9979 - accuracy: 0.6214 - val_loss: 1.0528 - val_accuracy: 0.6057 - 68ms/epoch - 3ms/step
# Epoch 317/600
# 24/24 - 0s - loss: 0.9974 - accuracy: 0.6214 - val_loss: 1.0525 - val_accuracy: 0.6057 - 63ms/epoch - 3ms/step
# Epoch 318/600
# 24/24 - 0s - loss: 0.9970 - accuracy: 0.6223 - val_loss: 1.0521 - val_accuracy: 0.6067 - 65ms/epoch - 3ms/step
# Epoch 319/600
# 24/24 - 0s - loss: 0.9965 - accuracy: 0.6214 - val_loss: 1.0517 - val_accuracy: 0.6067 - 74ms/epoch - 3ms/step
# Epoch 320/600
# 24/24 - 0s - loss: 0.9961 - accuracy: 0.6214 - val_loss: 1.0514 - val_accuracy: 0.6067 - 69ms/epoch - 3ms/step
# Epoch 321/600
# 24/24 - 0s - loss: 0.9956 - accuracy: 0.6214 - val_loss: 1.0511 - val_accuracy: 0.6057 - 65ms/epoch - 3ms/step
# Epoch 322/600
# 24/24 - 0s - loss: 0.9952 - accuracy: 0.6223 - val_loss: 1.0507 - val_accuracy: 0.6057 - 65ms/epoch - 3ms/step
# Epoch 323/600
# 24/24 - 0s - loss: 0.9947 - accuracy: 0.6219 - val_loss: 1.0503 - val_accuracy: 0.6057 - 64ms/epoch - 3ms/step
# Epoch 324/600
# 24/24 - 0s - loss: 0.9943 - accuracy: 0.6223 - val_loss: 1.0500 - val_accuracy: 0.6057 - 64ms/epoch - 3ms/step
# Epoch 325/600
# 24/24 - 0s - loss: 0.9938 - accuracy: 0.6219 - val_loss: 1.0497 - val_accuracy: 0.6067 - 63ms/epoch - 3ms/step
# Epoch 326/600
# 24/24 - 0s - loss: 0.9934 - accuracy: 0.6223 - val_loss: 1.0493 - val_accuracy: 0.6077 - 63ms/epoch - 3ms/step
# Epoch 327/600
# 24/24 - 0s - loss: 0.9929 - accuracy: 0.6214 - val_loss: 1.0489 - val_accuracy: 0.6077 - 65ms/epoch - 3ms/step
# Epoch 328/600
# 24/24 - 0s - loss: 0.9925 - accuracy: 0.6219 - val_loss: 1.0486 - val_accuracy: 0.6077 - 69ms/epoch - 3ms/step
# Epoch 329/600
# 24/24 - 0s - loss: 0.9920 - accuracy: 0.6210 - val_loss: 1.0482 - val_accuracy: 0.6077 - 65ms/epoch - 3ms/step
# Epoch 330/600
# 24/24 - 0s - loss: 0.9916 - accuracy: 0.6214 - val_loss: 1.0479 - val_accuracy: 0.6077 - 65ms/epoch - 3ms/step
# Epoch 331/600
# 24/24 - 0s - loss: 0.9911 - accuracy: 0.6210 - val_loss: 1.0475 - val_accuracy: 0.6077 - 67ms/epoch - 3ms/step
# Epoch 332/600
# 24/24 - 0s - loss: 0.9907 - accuracy: 0.6223 - val_loss: 1.0472 - val_accuracy: 0.6077 - 68ms/epoch - 3ms/step
# Epoch 333/600
# 24/24 - 0s - loss: 0.9903 - accuracy: 0.6223 - val_loss: 1.0468 - val_accuracy: 0.6087 - 63ms/epoch - 3ms/step
# Epoch 334/600
# 24/24 - 0s - loss: 0.9898 - accuracy: 0.6232 - val_loss: 1.0465 - val_accuracy: 0.6087 - 63ms/epoch - 3ms/step
# Epoch 335/600
# 24/24 - 0s - loss: 0.9894 - accuracy: 0.6236 - val_loss: 1.0462 - val_accuracy: 0.6087 - 63ms/epoch - 3ms/step
# Epoch 336/600
# 24/24 - 0s - loss: 0.9890 - accuracy: 0.6236 - val_loss: 1.0459 - val_accuracy: 0.6087 - 66ms/epoch - 3ms/step
# Epoch 337/600
# 24/24 - 0s - loss: 0.9886 - accuracy: 0.6236 - val_loss: 1.0456 - val_accuracy: 0.6087 - 67ms/epoch - 3ms/step
# Epoch 338/600
# 24/24 - 0s - loss: 0.9882 - accuracy: 0.6240 - val_loss: 1.0453 - val_accuracy: 0.6087 - 66ms/epoch - 3ms/step
# Epoch 339/600
# 24/24 - 0s - loss: 0.9878 - accuracy: 0.6240 - val_loss: 1.0451 - val_accuracy: 0.6087 - 63ms/epoch - 3ms/step
# Epoch 340/600
# 24/24 - 0s - loss: 0.9874 - accuracy: 0.6245 - val_loss: 1.0448 - val_accuracy: 0.6087 - 67ms/epoch - 3ms/step
# Epoch 341/600
# 24/24 - 0s - loss: 0.9870 - accuracy: 0.6245 - val_loss: 1.0445 - val_accuracy: 0.6087 - 67ms/epoch - 3ms/step
# Epoch 342/600
# 24/24 - 0s - loss: 0.9867 - accuracy: 0.6245 - val_loss: 1.0442 - val_accuracy: 0.6097 - 66ms/epoch - 3ms/step
# Epoch 343/600
# 24/24 - 0s - loss: 0.9863 - accuracy: 0.6245 - val_loss: 1.0439 - val_accuracy: 0.6097 - 64ms/epoch - 3ms/step
# Epoch 344/600
# 24/24 - 0s - loss: 0.9859 - accuracy: 0.6236 - val_loss: 1.0436 - val_accuracy: 0.6097 - 65ms/epoch - 3ms/step
# Epoch 345/600
# 24/24 - 0s - loss: 0.9855 - accuracy: 0.6236 - val_loss: 1.0433 - val_accuracy: 0.6097 - 63ms/epoch - 3ms/step
# Epoch 346/600
# 24/24 - 0s - loss: 0.9851 - accuracy: 0.6240 - val_loss: 1.0430 - val_accuracy: 0.6097 - 64ms/epoch - 3ms/step
# Epoch 347/600
# 24/24 - 0s - loss: 0.9847 - accuracy: 0.6240 - val_loss: 1.0427 - val_accuracy: 0.6097 - 63ms/epoch - 3ms/step
# Epoch 348/600
# 24/24 - 0s - loss: 0.9843 - accuracy: 0.6245 - val_loss: 1.0424 - val_accuracy: 0.6097 - 63ms/epoch - 3ms/step
# Epoch 349/600
# 24/24 - 0s - loss: 0.9839 - accuracy: 0.6240 - val_loss: 1.0422 - val_accuracy: 0.6097 - 66ms/epoch - 3ms/step
# Epoch 350/600
# 24/24 - 0s - loss: 0.9836 - accuracy: 0.6240 - val_loss: 1.0418 - val_accuracy: 0.6097 - 68ms/epoch - 3ms/step
# Epoch 351/600
# 24/24 - 0s - loss: 0.9832 - accuracy: 0.6245 - val_loss: 1.0415 - val_accuracy: 0.6097 - 63ms/epoch - 3ms/step
# Epoch 352/600
# 24/24 - 0s - loss: 0.9828 - accuracy: 0.6240 - val_loss: 1.0413 - val_accuracy: 0.6097 - 64ms/epoch - 3ms/step
# Epoch 353/600
# 24/24 - 0s - loss: 0.9824 - accuracy: 0.6245 - val_loss: 1.0410 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 354/600
# 24/24 - 0s - loss: 0.9820 - accuracy: 0.6245 - val_loss: 1.0407 - val_accuracy: 0.6097 - 65ms/epoch - 3ms/step
# Epoch 355/600
# 24/24 - 0s - loss: 0.9817 - accuracy: 0.6249 - val_loss: 1.0404 - val_accuracy: 0.6097 - 65ms/epoch - 3ms/step
# Epoch 356/600
# 24/24 - 0s - loss: 0.9813 - accuracy: 0.6245 - val_loss: 1.0402 - val_accuracy: 0.6097 - 67ms/epoch - 3ms/step
# Epoch 357/600
# 24/24 - 0s - loss: 0.9809 - accuracy: 0.6249 - val_loss: 1.0399 - val_accuracy: 0.6097 - 61ms/epoch - 3ms/step
# Epoch 358/600
# 24/24 - 0s - loss: 0.9805 - accuracy: 0.6240 - val_loss: 1.0396 - val_accuracy: 0.6097 - 61ms/epoch - 3ms/step
# Epoch 359/600
# 24/24 - 0s - loss: 0.9802 - accuracy: 0.6249 - val_loss: 1.0394 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 360/600
# 24/24 - 0s - loss: 0.9798 - accuracy: 0.6240 - val_loss: 1.0392 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 361/600
# 24/24 - 0s - loss: 0.9794 - accuracy: 0.6245 - val_loss: 1.0389 - val_accuracy: 0.6097 - 67ms/epoch - 3ms/step
# Epoch 362/600
# 24/24 - 0s - loss: 0.9791 - accuracy: 0.6240 - val_loss: 1.0386 - val_accuracy: 0.6087 - 66ms/epoch - 3ms/step
# Epoch 363/600
# 24/24 - 0s - loss: 0.9787 - accuracy: 0.6249 - val_loss: 1.0384 - val_accuracy: 0.6087 - 66ms/epoch - 3ms/step
# Epoch 364/600
# 24/24 - 0s - loss: 0.9784 - accuracy: 0.6245 - val_loss: 1.0381 - val_accuracy: 0.6087 - 66ms/epoch - 3ms/step
# Epoch 365/600
# 24/24 - 0s - loss: 0.9780 - accuracy: 0.6249 - val_loss: 1.0379 - val_accuracy: 0.6087 - 65ms/epoch - 3ms/step
# Epoch 366/600
# 24/24 - 0s - loss: 0.9776 - accuracy: 0.6249 - val_loss: 1.0376 - val_accuracy: 0.6087 - 64ms/epoch - 3ms/step
# Epoch 367/600
# 24/24 - 0s - loss: 0.9773 - accuracy: 0.6253 - val_loss: 1.0373 - val_accuracy: 0.6087 - 63ms/epoch - 3ms/step
# Epoch 368/600
# 24/24 - 0s - loss: 0.9769 - accuracy: 0.6253 - val_loss: 1.0371 - val_accuracy: 0.6087 - 64ms/epoch - 3ms/step
# Epoch 369/600
# 24/24 - 0s - loss: 0.9765 - accuracy: 0.6253 - val_loss: 1.0369 - val_accuracy: 0.6087 - 66ms/epoch - 3ms/step
# Epoch 370/600
# 24/24 - 0s - loss: 0.9762 - accuracy: 0.6253 - val_loss: 1.0366 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 371/600
# 24/24 - 0s - loss: 0.9758 - accuracy: 0.6253 - val_loss: 1.0364 - val_accuracy: 0.6087 - 62ms/epoch - 3ms/step
# Epoch 372/600
# 24/24 - 0s - loss: 0.9755 - accuracy: 0.6249 - val_loss: 1.0361 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 373/600
# 24/24 - 0s - loss: 0.9751 - accuracy: 0.6253 - val_loss: 1.0359 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 374/600
# 24/24 - 0s - loss: 0.9748 - accuracy: 0.6258 - val_loss: 1.0356 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 375/600
# 24/24 - 0s - loss: 0.9744 - accuracy: 0.6253 - val_loss: 1.0354 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 376/600
# 24/24 - 0s - loss: 0.9740 - accuracy: 0.6245 - val_loss: 1.0352 - val_accuracy: 0.6097 - 64ms/epoch - 3ms/step
# Epoch 377/600
# 24/24 - 0s - loss: 0.9737 - accuracy: 0.6245 - val_loss: 1.0349 - val_accuracy: 0.6097 - 70ms/epoch - 3ms/step
# Epoch 378/600
# 24/24 - 0s - loss: 0.9734 - accuracy: 0.6240 - val_loss: 1.0347 - val_accuracy: 0.6097 - 69ms/epoch - 3ms/step
# Epoch 379/600
# 24/24 - 0s - loss: 0.9731 - accuracy: 0.6236 - val_loss: 1.0345 - val_accuracy: 0.6097 - 67ms/epoch - 3ms/step
# Epoch 380/600
# 24/24 - 0s - loss: 0.9728 - accuracy: 0.6236 - val_loss: 1.0343 - val_accuracy: 0.6097 - 66ms/epoch - 3ms/step
# Epoch 381/600
# 24/24 - 0s - loss: 0.9725 - accuracy: 0.6236 - val_loss: 1.0341 - val_accuracy: 0.6097 - 62ms/epoch - 3ms/step
# Epoch 382/600
# 24/24 - 0s - loss: 0.9721 - accuracy: 0.6236 - val_loss: 1.0338 - val_accuracy: 0.6097 - 67ms/epoch - 3ms/step
# Epoch 383/600
# 24/24 - 0s - loss: 0.9718 - accuracy: 0.6232 - val_loss: 1.0336 - val_accuracy: 0.6097 - 67ms/epoch - 3ms/step
# Epoch 384/600
# 24/24 - 0s - loss: 0.9715 - accuracy: 0.6232 - val_loss: 1.0334 - val_accuracy: 0.6097 - 66ms/epoch - 3ms/step
# Epoch 385/600
# ...
# Epoch 492/600
# 24/24 - 0s - loss: 0.9446 - accuracy: 0.6275 - val_loss: 1.0166 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 493/600
# 24/24 - 0s - loss: 0.9444 - accuracy: 0.6271 - val_loss: 1.0165 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 494/600
# 24/24 - 0s - loss: 0.9442 - accuracy: 0.6275 - val_loss: 1.0164 - val_accuracy: 0.6168 - 71ms/epoch - 3ms/step
# Epoch 495/600
# 24/24 - 0s - loss: 0.9440 - accuracy: 0.6271 - val_loss: 1.0163 - val_accuracy: 0.6178 - 64ms/epoch - 3ms/step
# Epoch 496/600
# 24/24 - 0s - loss: 0.9438 - accuracy: 0.6271 - val_loss: 1.0163 - val_accuracy: 0.6168 - 60ms/epoch - 3ms/step
# Epoch 497/600
# 24/24 - 0s - loss: 0.9436 - accuracy: 0.6275 - val_loss: 1.0162 - val_accuracy: 0.6168 - 64ms/epoch - 3ms/step
# Epoch 498/600
# 24/24 - 0s - loss: 0.9434 - accuracy: 0.6275 - val_loss: 1.0161 - val_accuracy: 0.6168 - 67ms/epoch - 3ms/step
# Epoch 499/600
# 24/24 - 0s - loss: 0.9432 - accuracy: 0.6275 - val_loss: 1.0160 - val_accuracy: 0.6168 - 66ms/epoch - 3ms/step
# Epoch 500/600
# 24/24 - 0s - loss: 0.9430 - accuracy: 0.6275 - val_loss: 1.0159 - val_accuracy: 0.6168 - 66ms/epoch - 3ms/step
# Epoch 501/600
# 24/24 - 0s - loss: 0.9428 - accuracy: 0.6279 - val_loss: 1.0158 - val_accuracy: 0.6168 - 64ms/epoch - 3ms/step
# Epoch 502/600
# 24/24 - 0s - loss: 0.9426 - accuracy: 0.6284 - val_loss: 1.0157 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 503/600
# 24/24 - 0s - loss: 0.9424 - accuracy: 0.6284 - val_loss: 1.0156 - val_accuracy: 0.6168 - 62ms/epoch - 3ms/step
# Epoch 504/600
# 24/24 - 0s - loss: 0.9423 - accuracy: 0.6284 - val_loss: 1.0155 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 505/600
# 24/24 - 0s - loss: 0.9421 - accuracy: 0.6284 - val_loss: 1.0155 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 506/600
# 24/24 - 0s - loss: 0.9419 - accuracy: 0.6284 - val_loss: 1.0154 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 507/600
# 24/24 - 0s - loss: 0.9418 - accuracy: 0.6284 - val_loss: 1.0153 - val_accuracy: 0.6168 - 66ms/epoch - 3ms/step
# Epoch 508/600
# 24/24 - 0s - loss: 0.9416 - accuracy: 0.6284 - val_loss: 1.0152 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 509/600
# 24/24 - 0s - loss: 0.9414 - accuracy: 0.6284 - val_loss: 1.0151 - val_accuracy: 0.6178 - 61ms/epoch - 3ms/step
# Epoch 510/600
# 24/24 - 0s - loss: 0.9412 - accuracy: 0.6284 - val_loss: 1.0150 - val_accuracy: 0.6178 - 61ms/epoch - 3ms/step
# Epoch 511/600
# 24/24 - 0s - loss: 0.9411 - accuracy: 0.6284 - val_loss: 1.0149 - val_accuracy: 0.6178 - 63ms/epoch - 3ms/step
# Epoch 512/600
# 24/24 - 0s - loss: 0.9409 - accuracy: 0.6284 - val_loss: 1.0148 - val_accuracy: 0.6178 - 67ms/epoch - 3ms/step
# Epoch 513/600
# 24/24 - 0s - loss: 0.9407 - accuracy: 0.6284 - val_loss: 1.0147 - val_accuracy: 0.6178 - 65ms/epoch - 3ms/step
# Epoch 514/600
# 24/24 - 0s - loss: 0.9406 - accuracy: 0.6288 - val_loss: 1.0147 - val_accuracy: 0.6178 - 64ms/epoch - 3ms/step
# Epoch 515/600
# 24/24 - 0s - loss: 0.9404 - accuracy: 0.6288 - val_loss: 1.0146 - val_accuracy: 0.6178 - 61ms/epoch - 3ms/step
# Epoch 516/600
# 24/24 - 0s - loss: 0.9402 - accuracy: 0.6288 - val_loss: 1.0145 - val_accuracy: 0.6178 - 70ms/epoch - 3ms/step
# Epoch 517/600
# 24/24 - 0s - loss: 0.9401 - accuracy: 0.6288 - val_loss: 1.0144 - val_accuracy: 0.6178 - 68ms/epoch - 3ms/step
# Epoch 518/600
# 24/24 - 0s - loss: 0.9399 - accuracy: 0.6288 - val_loss: 1.0143 - val_accuracy: 0.6178 - 69ms/epoch - 3ms/step
# Epoch 519/600
# 24/24 - 0s - loss: 0.9397 - accuracy: 0.6288 - val_loss: 1.0143 - val_accuracy: 0.6178 - 67ms/epoch - 3ms/step
# Epoch 520/600
# 24/24 - 0s - loss: 0.9395 - accuracy: 0.6288 - val_loss: 1.0142 - val_accuracy: 0.6178 - 62ms/epoch - 3ms/step
# Epoch 521/600
# 24/24 - 0s - loss: 0.9394 - accuracy: 0.6284 - val_loss: 1.0141 - val_accuracy: 0.6178 - 63ms/epoch - 3ms/step
# Epoch 522/600
# 24/24 - 0s - loss: 0.9392 - accuracy: 0.6284 - val_loss: 1.0140 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 523/600
# 24/24 - 0s - loss: 0.9390 - accuracy: 0.6284 - val_loss: 1.0139 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 524/600
# 24/24 - 0s - loss: 0.9389 - accuracy: 0.6284 - val_loss: 1.0138 - val_accuracy: 0.6168 - 74ms/epoch - 3ms/step
# Epoch 525/600
# 24/24 - 0s - loss: 0.9387 - accuracy: 0.6284 - val_loss: 1.0137 - val_accuracy: 0.6168 - 73ms/epoch - 3ms/step
# Epoch 526/600
# 24/24 - 0s - loss: 0.9385 - accuracy: 0.6284 - val_loss: 1.0137 - val_accuracy: 0.6168 - 74ms/epoch - 3ms/step
# Epoch 527/600
# 24/24 - 0s - loss: 0.9384 - accuracy: 0.6279 - val_loss: 1.0136 - val_accuracy: 0.6168 - 68ms/epoch - 3ms/step
# Epoch 528/600
# 24/24 - 0s - loss: 0.9382 - accuracy: 0.6288 - val_loss: 1.0135 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 529/600
# 24/24 - 0s - loss: 0.9380 - accuracy: 0.6288 - val_loss: 1.0134 - val_accuracy: 0.6168 - 68ms/epoch - 3ms/step
# Epoch 530/600
# 24/24 - 0s - loss: 0.9379 - accuracy: 0.6288 - val_loss: 1.0134 - val_accuracy: 0.6168 - 64ms/epoch - 3ms/step
# Epoch 531/600
# 24/24 - 0s - loss: 0.9377 - accuracy: 0.6288 - val_loss: 1.0133 - val_accuracy: 0.6168 - 62ms/epoch - 3ms/step
# Epoch 532/600
# 24/24 - 0s - loss: 0.9375 - accuracy: 0.6288 - val_loss: 1.0132 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 533/600
# 24/24 - 0s - loss: 0.9374 - accuracy: 0.6284 - val_loss: 1.0131 - val_accuracy: 0.6168 - 67ms/epoch - 3ms/step
# Epoch 534/600
# 24/24 - 0s - loss: 0.9372 - accuracy: 0.6284 - val_loss: 1.0131 - val_accuracy: 0.6168 - 70ms/epoch - 3ms/step
# Epoch 535/600
# 24/24 - 0s - loss: 0.9370 - accuracy: 0.6284 - val_loss: 1.0130 - val_accuracy: 0.6178 - 69ms/epoch - 3ms/step
# Epoch 536/600
# 24/24 - 0s - loss: 0.9369 - accuracy: 0.6279 - val_loss: 1.0129 - val_accuracy: 0.6178 - 69ms/epoch - 3ms/step
# Epoch 537/600
# 24/24 - 0s - loss: 0.9367 - accuracy: 0.6288 - val_loss: 1.0128 - val_accuracy: 0.6178 - 68ms/epoch - 3ms/step
# Epoch 538/600
# 24/24 - 0s - loss: 0.9365 - accuracy: 0.6288 - val_loss: 1.0127 - val_accuracy: 0.6178 - 72ms/epoch - 3ms/step
# Epoch 539/600
# 24/24 - 0s - loss: 0.9364 - accuracy: 0.6288 - val_loss: 1.0127 - val_accuracy: 0.6178 - 67ms/epoch - 3ms/step
# Epoch 540/600
# 24/24 - 0s - loss: 0.9362 - accuracy: 0.6288 - val_loss: 1.0126 - val_accuracy: 0.6178 - 64ms/epoch - 3ms/step
# Epoch 541/600
# 24/24 - 0s - loss: 0.9360 - accuracy: 0.6292 - val_loss: 1.0125 - val_accuracy: 0.6178 - 62ms/epoch - 3ms/step
# Epoch 542/600
# 24/24 - 0s - loss: 0.9359 - accuracy: 0.6284 - val_loss: 1.0124 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 543/600
# 24/24 - 0s - loss: 0.9357 - accuracy: 0.6301 - val_loss: 1.0124 - val_accuracy: 0.6158 - 65ms/epoch - 3ms/step
# Epoch 544/600
# 24/24 - 0s - loss: 0.9356 - accuracy: 0.6301 - val_loss: 1.0123 - val_accuracy: 0.6158 - 67ms/epoch - 3ms/step
# Epoch 545/600
# 24/24 - 0s - loss: 0.9354 - accuracy: 0.6301 - val_loss: 1.0122 - val_accuracy: 0.6158 - 68ms/epoch - 3ms/step
# Epoch 546/600
# 24/24 - 0s - loss: 0.9353 - accuracy: 0.6305 - val_loss: 1.0122 - val_accuracy: 0.6158 - 66ms/epoch - 3ms/step
# Epoch 547/600
# 24/24 - 0s - loss: 0.9351 - accuracy: 0.6305 - val_loss: 1.0121 - val_accuracy: 0.6158 - 63ms/epoch - 3ms/step
# Epoch 548/600
# 24/24 - 0s - loss: 0.9350 - accuracy: 0.6305 - val_loss: 1.0120 - val_accuracy: 0.6158 - 63ms/epoch - 3ms/step
# Epoch 549/600
# 24/24 - 0s - loss: 0.9348 - accuracy: 0.6305 - val_loss: 1.0120 - val_accuracy: 0.6158 - 64ms/epoch - 3ms/step
# Epoch 550/600
# 24/24 - 0s - loss: 0.9347 - accuracy: 0.6305 - val_loss: 1.0119 - val_accuracy: 0.6158 - 63ms/epoch - 3ms/step
# Epoch 551/600
# 24/24 - 0s - loss: 0.9345 - accuracy: 0.6310 - val_loss: 1.0119 - val_accuracy: 0.6158 - 74ms/epoch - 3ms/step
# Epoch 552/600
# 24/24 - 0s - loss: 0.9344 - accuracy: 0.6314 - val_loss: 1.0118 - val_accuracy: 0.6158 - 69ms/epoch - 3ms/step
# Epoch 553/600
# 24/24 - 0s - loss: 0.9343 - accuracy: 0.6318 - val_loss: 1.0117 - val_accuracy: 0.6158 - 66ms/epoch - 3ms/step
# Epoch 554/600
# 24/24 - 0s - loss: 0.9341 - accuracy: 0.6323 - val_loss: 1.0116 - val_accuracy: 0.6158 - 68ms/epoch - 3ms/step
# Epoch 555/600
# 24/24 - 0s - loss: 0.9340 - accuracy: 0.6318 - val_loss: 1.0116 - val_accuracy: 0.6158 - 68ms/epoch - 3ms/step
# Epoch 556/600
# 24/24 - 0s - loss: 0.9338 - accuracy: 0.6318 - val_loss: 1.0115 - val_accuracy: 0.6158 - 68ms/epoch - 3ms/step
# Epoch 557/600
# 24/24 - 0s - loss: 0.9337 - accuracy: 0.6314 - val_loss: 1.0114 - val_accuracy: 0.6158 - 68ms/epoch - 3ms/step
# Epoch 558/600
# 24/24 - 0s - loss: 0.9335 - accuracy: 0.6314 - val_loss: 1.0114 - val_accuracy: 0.6168 - 71ms/epoch - 3ms/step
# Epoch 559/600
# 24/24 - 0s - loss: 0.9334 - accuracy: 0.6310 - val_loss: 1.0113 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 560/600
# 24/24 - 0s - loss: 0.9332 - accuracy: 0.6318 - val_loss: 1.0112 - val_accuracy: 0.6168 - 74ms/epoch - 3ms/step
# Epoch 561/600
# 24/24 - 0s - loss: 0.9331 - accuracy: 0.6314 - val_loss: 1.0112 - val_accuracy: 0.6168 - 67ms/epoch - 3ms/step
# Epoch 562/600
# 24/24 - 0s - loss: 0.9330 - accuracy: 0.6318 - val_loss: 1.0111 - val_accuracy: 0.6168 - 65ms/epoch - 3ms/step
# Epoch 563/600
# 24/24 - 0s - loss: 0.9328 - accuracy: 0.6318 - val_loss: 1.0110 - val_accuracy: 0.6168 - 109ms/epoch - 5ms/step
# Epoch 564/600
# 24/24 - 0s - loss: 0.9327 - accuracy: 0.6323 - val_loss: 1.0110 - val_accuracy: 0.6168 - 77ms/epoch - 3ms/step
# Epoch 565/600
# 24/24 - 0s - loss: 0.9325 - accuracy: 0.6323 - val_loss: 1.0109 - val_accuracy: 0.6168 - 73ms/epoch - 3ms/step
# Epoch 566/600
# 24/24 - 0s - loss: 0.9324 - accuracy: 0.6323 - val_loss: 1.0108 - val_accuracy: 0.6168 - 75ms/epoch - 3ms/step
# Epoch 567/600
# 24/24 - 0s - loss: 0.9323 - accuracy: 0.6323 - val_loss: 1.0108 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 568/600
# 24/24 - 0s - loss: 0.9321 - accuracy: 0.6323 - val_loss: 1.0107 - val_accuracy: 0.6168 - 72ms/epoch - 3ms/step
# Epoch 569/600
# 24/24 - 0s - loss: 0.9320 - accuracy: 0.6323 - val_loss: 1.0106 - val_accuracy: 0.6168 - 77ms/epoch - 3ms/step
# Epoch 570/600
# 24/24 - 0s - loss: 0.9318 - accuracy: 0.6327 - val_loss: 1.0106 - val_accuracy: 0.6168 - 75ms/epoch - 3ms/step
# Epoch 571/600
# 24/24 - 0s - loss: 0.9317 - accuracy: 0.6323 - val_loss: 1.0105 - val_accuracy: 0.6168 - 66ms/epoch - 3ms/step
# Epoch 572/600
# 24/24 - 0s - loss: 0.9316 - accuracy: 0.6323 - val_loss: 1.0104 - val_accuracy: 0.6168 - 70ms/epoch - 3ms/step
# Epoch 573/600
# 24/24 - 0s - loss: 0.9314 - accuracy: 0.6327 - val_loss: 1.0104 - val_accuracy: 0.6168 - 74ms/epoch - 3ms/step
# Epoch 574/600
# 24/24 - 0s - loss: 0.9313 - accuracy: 0.6323 - val_loss: 1.0103 - val_accuracy: 0.6168 - 69ms/epoch - 3ms/step
# Epoch 575/600
# 24/24 - 0s - loss: 0.9311 - accuracy: 0.6323 - val_loss: 1.0103 - val_accuracy: 0.6158 - 74ms/epoch - 3ms/step
# Epoch 576/600
# 24/24 - 0s - loss: 0.9310 - accuracy: 0.6331 - val_loss: 1.0102 - val_accuracy: 0.6158 - 66ms/epoch - 3ms/step
# Epoch 577/600
# 24/24 - 0s - loss: 0.9309 - accuracy: 0.6327 - val_loss: 1.0101 - val_accuracy: 0.6158 - 71ms/epoch - 3ms/step
# Epoch 578/600
# 24/24 - 0s - loss: 0.9307 - accuracy: 0.6323 - val_loss: 1.0101 - val_accuracy: 0.6158 - 71ms/epoch - 3ms/step
# Epoch 579/600
# 24/24 - 0s - loss: 0.9306 - accuracy: 0.6323 - val_loss: 1.0100 - val_accuracy: 0.6158 - 66ms/epoch - 3ms/step
# Epoch 580/600
# 24/24 - 0s - loss: 0.9304 - accuracy: 0.6327 - val_loss: 1.0099 - val_accuracy: 0.6158 - 70ms/epoch - 3ms/step
# Epoch 581/600
# 24/24 - 0s - loss: 0.9303 - accuracy: 0.6323 - val_loss: 1.0099 - val_accuracy: 0.6158 - 72ms/epoch - 3ms/step
# Epoch 582/600
# 24/24 - 0s - loss: 0.9302 - accuracy: 0.6323 - val_loss: 1.0098 - val_accuracy: 0.6158 - 72ms/epoch - 3ms/step
# Epoch 583/600
# 24/24 - 0s - loss: 0.9300 - accuracy: 0.6336 - val_loss: 1.0097 - val_accuracy: 0.6158 - 70ms/epoch - 3ms/step
# Epoch 584/600
# 24/24 - 0s - loss: 0.9299 - accuracy: 0.6336 - val_loss: 1.0097 - val_accuracy: 0.6158 - 71ms/epoch - 3ms/step
# Epoch 585/600
# 24/24 - 0s - loss: 0.9297 - accuracy: 0.6340 - val_loss: 1.0097 - val_accuracy: 0.6158 - 70ms/epoch - 3ms/step
# Epoch 586/600
# 24/24 - 0s - loss: 0.9296 - accuracy: 0.6340 - val_loss: 1.0096 - val_accuracy: 0.6158 - 66ms/epoch - 3ms/step
# Epoch 587/600
# 24/24 - 0s - loss: 0.9295 - accuracy: 0.6340 - val_loss: 1.0095 - val_accuracy: 0.6158 - 74ms/epoch - 3ms/step
# Epoch 588/600
# 24/24 - 0s - loss: 0.9294 - accuracy: 0.6340 - val_loss: 1.0095 - val_accuracy: 0.6158 - 75ms/epoch - 3ms/step
# Epoch 589/600
# 24/24 - 0s - loss: 0.9292 - accuracy: 0.6340 - val_loss: 1.0094 - val_accuracy: 0.6158 - 76ms/epoch - 3ms/step
# Epoch 590/600
# 24/24 - 0s - loss: 0.9291 - accuracy: 0.6344 - val_loss: 1.0094 - val_accuracy: 0.6148 - 76ms/epoch - 3ms/step
# Epoch 591/600
# 24/24 - 0s - loss: 0.9290 - accuracy: 0.6349 - val_loss: 1.0093 - val_accuracy: 0.6148 - 71ms/epoch - 3ms/step
# Epoch 592/600
# 24/24 - 0s - loss: 0.9289 - accuracy: 0.6349 - val_loss: 1.0093 - val_accuracy: 0.6148 - 69ms/epoch - 3ms/step
# Epoch 593/600
# 24/24 - 0s - loss: 0.9287 - accuracy: 0.6349 - val_loss: 1.0092 - val_accuracy: 0.6148 - 66ms/epoch - 3ms/step
# Epoch 594/600
# 24/24 - 0s - loss: 0.9286 - accuracy: 0.6349 - val_loss: 1.0091 - val_accuracy: 0.6158 - 66ms/epoch - 3ms/step
# Epoch 595/600
# 24/24 - 0s - loss: 0.9285 - accuracy: 0.6349 - val_loss: 1.0091 - val_accuracy: 0.6158 - 69ms/epoch - 3ms/step
# Epoch 596/600
# 24/24 - 0s - loss: 0.9284 - accuracy: 0.6349 - val_loss: 1.0090 - val_accuracy: 0.6148 - 73ms/epoch - 3ms/step
# Epoch 597/600
# 24/24 - 0s - loss: 0.9282 - accuracy: 0.6349 - val_loss: 1.0090 - val_accuracy: 0.6148 - 71ms/epoch - 3ms/step
# Epoch 598/600
# 24/24 - 0s - loss: 0.9281 - accuracy: 0.6349 - val_loss: 1.0089 - val_accuracy: 0.6148 - 69ms/epoch - 3ms/step
# Epoch 599/600
# 24/24 - 0s - loss: 0.9280 - accuracy: 0.6349 - val_loss: 1.0089 - val_accuracy: 0.6148 - 65ms/epoch - 3ms/step
# Epoch 600/600
# 24/24 - 0s - loss: 0.9278 - accuracy: 0.6349 - val_loss: 1.0088 - val_accuracy: 0.6138 - 76ms/epoch - 3ms/step
# Model: "tab_net_classifier_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_2 (TabNet)          multiple                  2582
#
#  classifier (Dense)          multiple                  25
#
# =================================================================
# Total params: 2,607
# Trainable params: 2,607
# Non-trainable params: 0
# _________________________________________________________________
# Model: "tab_net_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_features_2 (DenseFeat  multiple                 0
#  ures)
#
#  input_gn (GroupNormalizatio  multiple                 32
#  n)
#
#  transform_block_8 (Transfor  multiple                 612
#  mBlock)
#
#  transform_block_9 (Transfor  multiple                 646
#  mBlock)
#
#  transform_block_10 (Transfo  multiple                 646
#  rmBlock)
#
#  transform_block_11 (Transfo  multiple                 646
#  rmBlock)
#
# =================================================================
# Total params: 2,582
# Trainable params: 2,582
# Non-trainable params: 0
# _________________________________________________________________

# %%
print()
if os.path.exists('logs/'):
    shutil.rmtree('logs/')

""" Save the images of the feature masks """
# Force eager execution mode to generate the masks
x, y = next(iter(ds_train))
_ = model(x)

writer = tf.summary.create_file_writer("logs/")
with writer.as_default():
    for i, mask in enumerate(model.tabnet.feature_selection_masks):
        print("Saving mask {} of shape {}".format(i + 1, mask.shape))
        tf.summary.image('mask_at_iter_{}'.format(i + 1), step=0, data=mask, max_outputs=1)
        writer.flush()

    agg_mask = model.tabnet.aggregate_feature_selection_mask
    print("Saving aggregate mask of shape", agg_mask.shape)
    tf.summary.image("Aggregate Mask", step=0, data=agg_mask, max_outputs=1)
    writer.flush()

writer.close()
# Out:
# Saving aggregate mask of shape (1, 100, 16, 1)

# %%
y_pred = np.argmax(model.predict(ds_test), axis=-1)
report = classification_report(y_test, y_pred)
print(report)
# Out:
# 10/10 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.60      0.88      0.71       259
#            1       0.72      0.73      0.72       203
#            2       0.46      0.14      0.21       239
#            3       0.53      0.71      0.61       137
#            4       0.67      0.68      0.67       151
#
#     accuracy                           0.61       989
#    macro avg       0.60      0.63      0.59       989
# weighted avg       0.59      0.61      0.57       989

# %%
con_mat = tf.math.confusion_matrix(labels=y_test, predictions=y_pred).numpy()
con_mat_norm = np.around(con_mat.astype('float')/con_mat.sum(axis=1)[:, np.newaxis],
                         decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm, index=class_names_complete, columns=class_names_complete)

print('Accuracy Y_test: ', accuracy_score(y_test, y_pred))
figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True, cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Accuracy Y_test:  0.6137512639029322

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
